# %%
import pandas as pd

# %%
import datetime

# %%
def save_double_column_df(df, file_name, startrow = 0, **kwargs):
    '''Function to save doublecolumn DataFrame, to xlwriter'''
    # https://stackoverflow.com/questions/52497554/blank-line-below-headers-created-when-using-multiindex-and-to-excel-in-python
    
    # inputs:
    # df - pandas dataframe to save
    # xl_writer - book for saving
    # startrow - row from wich data frame will begins
    # **kwargs - arguments of `to_excel` function of DataFrame`
    with pd.ExcelWriter(file_name, mode='w') as writer:
        df.drop(df.index).to_excel(writer, startrow = startrow, **kwargs,index=False)
        df.to_excel(writer, startrow = startrow + 1, header = False, **kwargs,index=False)

# %%
data
# Out:
#                                                       \
#       성명          영문명 체류비자   국적          주민등록번호 여권번호
# 0    이동명  LI DONGMING  F-4   중국  700426-1182619  NaN
# 1      A          NaN  NaN  NaN  640607-1011421  NaN
# 2      B          NaN  NaN  NaN  911108-1169428  NaN
# 3      C          NaN  NaN  NaN  620318-5780290  NaN
# 4      D          NaN  NaN  NaN  731120-5780179  NaN
# ..   ...          ...  ...  ...             ...  ...
# 60  JJJJ          NaN  NaN  NaN  770419-5820010  NaN
# 61  KKKK          NaN  NaN  NaN  990413-1009721  NaN
# 62  LLLL          NaN  NaN  NaN  960706-1157010  NaN
# 63  MMMM          NaN  NaN  NaN  900518-5100044  NaN
# 64  NNNN          NaN  NaN  NaN  810119-5100019  NaN
#
#                                       2024-01-01
#                                    주소         측정       실
# 0             경기도 광주시 고불로78길 50, 101호     270000  170000
# 1               경기도 성남시 둔촌대로349번길 7-1     170000  100000
# 2                                 NaN     240000  240000
# 3           서울특별시 중랑구 중랑천로20길 9, 202호     250000  150000
# 4         경기도 수원시 팔달구 고화로 14번길14,302호     160000  250000
# ..                                ...        ...     ...
# 60            서울특별시 동대문구 홍릉로3길 44, 3층     210000  130000
# 61      인천광역시 부평구 경원대로 1269 108동 304호     240000  200000
# 62             인천 서구 청마로92, 402동 904호     100000  160000
# 63  경기도 부천시 소사구 은성로24번길 14, 102동 202호     150000  300000
# 64                                NaN     250000  160000
#
# [65 rows x 9 columns]

# %%
save_double_column_df(data,"./static/data/작업공수/작업자입력2.xlsx")

# %%
data = pd.read_excel("./static/data/작업공수/작업자입력.xlsx",header=[0,1])

# %%
data
# Out:
#                                                       \
#       성명          영문명 체류비자   국적          주민등록번호 여권번호
# 0    이동명  LI DONGMING  F-4   중국  700426-1182619  NaN
# 1      A          NaN  NaN  NaN  640607-1011421  NaN
# 2      B          NaN  NaN  NaN  911108-1169428  NaN
# 3      C          NaN  NaN  NaN  620318-5780290  NaN
# 4      D          NaN  NaN  NaN  731120-5780179  NaN
# ..   ...          ...  ...  ...             ...  ...
# 60  JJJJ          NaN  NaN  NaN  770419-5820010  NaN
# 61  KKKK          NaN  NaN  NaN  990413-1009721  NaN
# 62  LLLL          NaN  NaN  NaN  960706-1157010  NaN
# 63  MMMM          NaN  NaN  NaN  900518-5100044  NaN
# 64  NNNN          NaN  NaN  NaN  810119-5100019  NaN
#
#                                       2024-01-01
#                                    주소         측정       실
# 0             경기도 광주시 고불로78길 50, 101호     270000  170000
# 1               경기도 성남시 둔촌대로349번길 7-1     170000  100000
# 2                                 NaN     240000  240000
# 3           서울특별시 중랑구 중랑천로20길 9, 202호     250000  150000
# 4         경기도 수원시 팔달구 고화로 14번길14,302호     160000  250000
# ..                                ...        ...     ...
# 60            서울특별시 동대문구 홍릉로3길 44, 3층     210000  130000
# 61      인천광역시 부평구 경원대로 1269 108동 304호     240000  200000
# 62             인천 서구 청마로92, 402동 904호     100000  160000
# 63  경기도 부천시 소사구 은성로24번길 14, 102동 202호     150000  300000
# 64                                NaN     250000  160000
#
# [65 rows x 9 columns]

# %%
new_columns = [
    (("" if "Unnamed" in str(outer) else outer.strftime('%Y-%m-%d') if isinstance(outer, datetime.datetime) else outer), inner)
    for outer, inner in data.columns
]

# 새로운 컬럼 이름을 적용
data.columns = pd.MultiIndex.from_tuples(new_columns)

# %%
data
# Out:
#                                                       \
#       성명          영문명 체류비자   국적          주민등록번호 여권번호
# 0    이동명  LI DONGMING  F-4   중국  700426-1182619  NaN
# 1      A          NaN  NaN  NaN  640607-1011421  NaN
# 2      B          NaN  NaN  NaN  911108-1169428  NaN
# 3      C          NaN  NaN  NaN  620318-5780290  NaN
# 4      D          NaN  NaN  NaN  731120-5780179  NaN
# ..   ...          ...  ...  ...             ...  ...
# 60  JJJJ          NaN  NaN  NaN  770419-5820010  NaN
# 61  KKKK          NaN  NaN  NaN  990413-1009721  NaN
# 62  LLLL          NaN  NaN  NaN  960706-1157010  NaN
# 63  MMMM          NaN  NaN  NaN  900518-5100044  NaN
# 64  NNNN          NaN  NaN  NaN  810119-5100019  NaN
#
#                                       2024-01-01
#                                    주소         측정       실
# 0             경기도 광주시 고불로78길 50, 101호     270000  170000
# 1               경기도 성남시 둔촌대로349번길 7-1     170000  100000
# 2                                 NaN     240000  240000
# 3           서울특별시 중랑구 중랑천로20길 9, 202호     250000  150000
# 4         경기도 수원시 팔달구 고화로 14번길14,302호     160000  250000
# ..                                ...        ...     ...
# 60            서울특별시 동대문구 홍릉로3길 44, 3층     210000  130000
# 61      인천광역시 부평구 경원대로 1269 108동 304호     240000  200000
# 62             인천 서구 청마로92, 402동 904호     100000  160000
# 63  경기도 부천시 소사구 은성로24번길 14, 102동 202호     150000  300000
# 64                                NaN     250000  160000
#
# [65 rows x 9 columns]

# %%
data.to_excel("./static/data/작업공수/작업자입력2.xlsx",index_label=False,header)

# %%
data
# Out:
#                                                       \
#       성명          영문명 체류비자   국적          주민등록번호 여권번호
# 0    NaN          NaN  NaN  NaN             NaN  NaN
# 1    NaN          NaN  NaN  NaN             NaN  NaN
# 2    이동명  LI DONGMING  F-4   중국  700426-1182619  NaN
# 3      A          NaN  NaN  NaN  640607-1011421  NaN
# 4      B          NaN  NaN  NaN  911108-1169428  NaN
# ..   ...          ...  ...  ...             ...  ...
# 62  JJJJ          NaN  NaN  NaN  770419-5820010  NaN
# 63  KKKK          NaN  NaN  NaN  990413-1009721  NaN
# 64  LLLL          NaN  NaN  NaN  960706-1157010  NaN
# 65  MMMM          NaN  NaN  NaN  900518-5100044  NaN
# 66  NNNN          NaN  NaN  NaN  810119-5100019  NaN
#
#                                       2024-01-01
#                                    주소         측정         실
# 0                                 NaN        NaN       NaN
# 1                                 NaN        NaN       NaN
# 2             경기도 광주시 고불로78길 50, 101호   270000.0  170000.0
# 3               경기도 성남시 둔촌대로349번길 7-1   170000.0  100000.0
# 4                                 NaN   240000.0  240000.0
# ..                                ...        ...       ...
# 62            서울특별시 동대문구 홍릉로3길 44, 3층   210000.0  130000.0
# 63      인천광역시 부평구 경원대로 1269 108동 304호   240000.0  200000.0
# 64             인천 서구 청마로92, 402동 904호   100000.0  160000.0
# 65  경기도 부천시 소사구 은성로24번길 14, 102동 202호   150000.0  300000.0
# 66                                NaN   250000.0  160000.0
#
# [67 rows x 9 columns]

# %%
data = pd.read_excel("./static/data/작업공수/작업자입력2.xlsx",header=[0,1])

# %%
data
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#    Unnamed: 0_level_1                 성명                영문명
# 0                 NaN                NaN                NaN
# 1                 0.0                이동명        LI DONGMING
# 2                 1.0                  A                NaN
# 3                 2.0                  B                NaN
# 4                 3.0                  C                NaN
# ..                ...                ...                ...
# 61               60.0               JJJJ                NaN
# 62               61.0               KKKK                NaN
# 63               62.0               LLLL                NaN
# 64               63.0               MMMM                NaN
# 65               64.0               NNNN                NaN
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                  체류비자                 국적             주민등록번호
# 0                 NaN                NaN                NaN
# 1                 F-4                 중국     700426-1182619
# 2                 NaN                NaN     640607-1011421
# 3                 NaN                NaN     911108-1169428
# 4                 NaN                NaN     620318-5780290
# ..                ...                ...                ...
# 61                NaN                NaN     770419-5820010
# 62                NaN                NaN     990413-1009721
# 63                NaN                NaN     960706-1157010
# 64                NaN                NaN     900518-5100044
# 65                NaN                NaN     810119-5100019
#
#    Unnamed: 6_level_0                 Unnamed: 7_level_0 2024-01-01
#                  여권번호                                 주소         측정         실
# 0                 NaN                                NaN        NaN       NaN
# 1                 NaN            경기도 광주시 고불로78길 50, 101호   270000.0  170000.0
# 2                 NaN              경기도 성남시 둔촌대로349번길 7-1   170000.0  100000.0
# 3                 NaN                                NaN   240000.0  240000.0
# 4                 NaN          서울특별시 중랑구 중랑천로20길 9, 202호   250000.0  150000.0
# ..                ...                                ...        ...       ...
# 61                NaN            서울특별시 동대문구 홍릉로3길 44, 3층   210000.0  130000.0
# 62                NaN      인천광역시 부평구 경원대로 1269 108동 304호   240000.0  200000.0
# 63                NaN             인천 서구 청마로92, 402동 904호   100000.0  160000.0
# 64                NaN  경기도 부천시 소사구 은성로24번길 14, 102동 202호   150000.0  300000.0
# 65                NaN                                NaN   250000.0  160000.0
#
# [66 rows x 10 columns]

# %%
data = data[2:]

# %%
index = pd.MultiIndex.from_tuples(
    [('2024-01-01', '측정'), ('2024-01-02', '측정'), ('2024-01-03', '측정')],
    names=['날짜', '종류']
)

# %%
index
# Out:
# MultiIndex([('2024-01-01', '측정'),
#             ('2024-01-02', '측정'),
#             ('2024-01-03', '측정')],
#            names=['날짜', '종류'])

# %%
 data.columns
# Out:
# MultiIndex([(                ' ',     '성명'),
#             (                ' ',    '영문명'),
#             (                ' ',   '체류비자'),
#             (                ' ',     '국적'),
#             (                ' ', '주민등록번호'),
#             (                ' ',   '여권번호'),
#             (                ' ',     '직종'),
#             (2024-01-01 00:00:00,     '측정'),
#             (2024-01-01 00:00:00,      '실'),
#             (2024-01-02 00:00:00,     '측정'),
#             (2024-01-02 00:00:00,      '실')],
#            )

# %%
if ('2024-01-03', '측정') in data.columns:
    print("있으니깐 패스")
else:
    data2 = pd.DataFrame({
        ('2024-01-03', '측정'): [],
        ('2024-01-03', '실'): [],
    })
    data = pd.concat([data,data2],axis=0)

## 사람만큼 공수 추가 (일반은 1, 오전,특수는 0.5)
data.loc[data[('Unnamed: 0_level_0',     '성명')]=='A',('2024-01-03', '측정')] += 1
# Out:
# 있으니깐 패스

# %%
data3
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                    성명                영문명               체류비자
# 0                 이동명        LI DONGMING                F-4
# 1                   A                NaN                NaN
# 2                   B                NaN                NaN
# 3                   C                NaN                NaN
# 4                   D                NaN                NaN
# ..                ...                ...                ...
# 60               JJJJ                NaN                NaN
# 61               KKKK                NaN                NaN
# 62               LLLL                NaN                NaN
# 63               MMMM                NaN                NaN
# 64               NNNN                NaN                NaN
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                    국적             주민등록번호               여권번호
# 0                  중국     700426-1182619                NaN
# 1                 NaN     640607-1011421                NaN
# 2                 NaN     911108-1169428                NaN
# 3                 NaN     620318-5780290                NaN
# 4                 NaN     731120-5780179                NaN
# ..                ...                ...                ...
# 60                NaN     770419-5820010                NaN
# 61                NaN     990413-1009721                NaN
# 62                NaN     960706-1157010                NaN
# 63                NaN     900518-5100044                NaN
# 64                NaN     810119-5100019                NaN
#
#    Unnamed: 6_level_0 2024-01-01 00:00:00      2024-01-02 00:00:00       \
#                    직종                  측정    실                  측정    실
# 0                  형틀                 1.0  1.0                 0.8  1.0
# 1                  알폼                 1.0  1.0                 1.0  0.4
# 2                  갱폼                 1.0  1.0                 NaN  1.0
# 3                 NaN                 1.0  1.0                 1.0  1.0
# 4                 NaN                 1.0  NaN                 NaN  1.0
# ..                ...                 ...  ...                 ...  ...
# 60                NaN                 1.0  1.0                 1.0  NaN
# 61                NaN                 0.1  1.0                 NaN  1.0
# 62                NaN                 1.0  1.0                 2.0  1.0
# 63                NaN                 1.0  1.0                 NaN  1.0
# 64                NaN                 1.0  1.0                 1.0  1.0
#
#    2024-01-03
#            측정   실
# 0         NaN NaN
# 1         3.0 NaN
# 2         NaN NaN
# 3         NaN NaN
# 4         NaN NaN
# ..        ...  ..
# 60        NaN NaN
# 61        NaN NaN
# 62        NaN NaN
# 63        NaN NaN
# 64        NaN NaN
#
# [65 rows x 13 columns]

# %%
import os

# 특정 폴더 경로 설정
parent_directory = "./static/data/개인화폴더"

# A0001부터 A9999까지의 폴더 생성
for i in range(1, 10000):
    folder_name = f"A{i:04d}"  # A0001, A0002, ..., A9999 형식으로 생성
    folder_path = os.path.join(parent_directory, folder_name)
    
    # 폴더가 존재하지 않으면 생성
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)
        print(f"Created folder: {folder_path}")
    else:
        print(f"Folder already exists: {folder_path}")

print("Folder creation completed.")
# Out:
# Created folder: ./static/data/개인화폴더\A0001
# Created folder: ./static/data/개인화폴더\A0002
# Created folder: ./static/data/개인화폴더\A0003
# Created folder: ./static/data/개인화폴더\A0004
# Created folder: ./static/data/개인화폴더\A0005
# Created folder: ./static/data/개인화폴더\A0006
# Created folder: ./static/data/개인화폴더\A0007
# Created folder: ./static/data/개인화폴더\A0008
# Created folder: ./static/data/개인화폴더\A0009
# Created folder: ./static/data/개인화폴더\A0010
# Created folder: ./static/data/개인화폴더\A0011
# Created folder: ./static/data/개인화폴더\A0012
# Created folder: ./static/data/개인화폴더\A0013
# Created folder: ./static/data/개인화폴더\A0014
# Created folder: ./static/data/개인화폴더\A0015
# Created folder: ./static/data/개인화폴더\A0016
# Created folder: ./static/data/개인화폴더\A0017
# Created folder: ./static/data/개인화폴더\A0018
# Created folder: ./static/data/개인화폴더\A0019
# Created folder: ./static/data/개인화폴더\A0020
# Created folder: ./static/data/개인화폴더\A0021
# Created folder: ./static/data/개인화폴더\A0022
# Created folder: ./static/data/개인화폴더\A0023
# Created folder: ./static/data/개인화폴더\A0024
# Created folder: ./static/data/개인화폴더\A0025
# Created folder: ./static/data/개인화폴더\A0026
# Created folder: ./static/data/개인화폴더\A0027
# Created folder: ./static/data/개인화폴더\A0028
# Created folder: ./static/data/개인화폴더\A0029
# Created folder: ./static/data/개인화폴더\A0030
# Created folder: ./static/data/개인화폴더\A0031
# Created folder: ./static/data/개인화폴더\A0032
# Created folder: ./static/data/개인화폴더\A0033
# Created folder: ./static/data/개인화폴더\A0034
# Created folder: ./static/data/개인화폴더\A0035
# Created folder: ./static/data/개인화폴더\A0036
# Created folder: ./static/data/개인화폴더\A0037
# Created folder: ./static/data/개인화폴더\A0038
# Created folder: ./static/data/개인화폴더\A0039
# Created folder: ./static/data/개인화폴더\A0040
# Created folder: ./static/data/개인화폴더\A0041
# Created folder: ./static/data/개인화폴더\A0042
# Created folder: ./static/data/개인화폴더\A0043
# Created folder: ./static/data/개인화폴더\A0044
# Created folder: ./static/data/개인화폴더\A0045
# Created folder: ./static/data/개인화폴더\A0046
# Created folder: ./static/data/개인화폴더\A0047
# Created folder: ./static/data/개인화폴더\A0048
# Created folder: ./static/data/개인화폴더\A0049
# Created folder: ./static/data/개인화폴더\A0050
# Created folder: ./static/data/개인화폴더\A0051
# Created folder: ./static/data/개인화폴더\A0052
# Created folder: ./static/data/개인화폴더\A0053
# Created folder: ./static/data/개인화폴더\A0054
# Created folder: ./static/data/개인화폴더\A0055
# Created folder: ./static/data/개인화폴더\A0056
# Created folder: ./static/data/개인화폴더\A0057
# Created folder: ./static/data/개인화폴더\A0058
# Created folder: ./static/data/개인화폴더\A0059
# Created folder: ./static/data/개인화폴더\A0060
# Created folder: ./static/data/개인화폴더\A0061
# Created folder: ./static/data/개인화폴더\A0062
# Created folder: ./static/data/개인화폴더\A0063
# Created folder: ./static/data/개인화폴더\A0064
# Created folder: ./static/data/개인화폴더\A0065
# Created folder: ./static/data/개인화폴더\A0066
# Created folder: ./static/data/개인화폴더\A0067
# Created folder: ./static/data/개인화폴더\A0068
# Created folder: ./static/data/개인화폴더\A0069
# Created folder: ./static/data/개인화폴더\A0070
# Created folder: ./static/data/개인화폴더\A0071
# Created folder: ./static/data/개인화폴더\A0072
# Created folder: ./static/data/개인화폴더\A0073
# Created folder: ./static/data/개인화폴더\A0074
# Created folder: ./static/data/개인화폴더\A0075
# Created folder: ./static/data/개인화폴더\A0076
# Created folder: ./static/data/개인화폴더\A0077
# Created folder: ./static/data/개인화폴더\A0078
# Created folder: ./static/data/개인화폴더\A0079
# Created folder: ./static/data/개인화폴더\A0080
# Created folder: ./static/data/개인화폴더\A0081
# Created folder: ./static/data/개인화폴더\A0082
# Created folder: ./static/data/개인화폴더\A0083
# Created folder: ./static/data/개인화폴더\A0084
# Created folder: ./static/data/개인화폴더\A0085
# Created folder: ./static/data/개인화폴더\A0086
# Created folder: ./static/data/개인화폴더\A0087
# Created folder: ./static/data/개인화폴더\A0088
# Created folder: ./static/data/개인화폴더\A0089
# Created folder: ./static/data/개인화폴더\A0090
# Created folder: ./static/data/개인화폴더\A0091
# Created folder: ./static/data/개인화폴더\A0092
# Created folder: ./static/data/개인화폴더\A0093
# Created folder: ./static/data/개인화폴더\A0094
# Created folder: ./static/data/개인화폴더\A0095
# Created folder: ./static/data/개인화폴더\A0096
# Created folder: ./static/data/개인화폴더\A0097
# Created folder: ./static/data/개인화폴더\A0098
# Created folder: ./static/data/개인화폴더\A0099
# Created folder: ./static/data/개인화폴더\A0100
# Created folder: ./static/data/개인화폴더\A0101
# Created folder: ./static/data/개인화폴더\A0102
# Created folder: ./static/data/개인화폴더\A0103
# Created folder: ./static/data/개인화폴더\A0104
# Created folder: ./static/data/개인화폴더\A0105
# Created folder: ./static/data/개인화폴더\A0106
# Created folder: ./static/data/개인화폴더\A0107
# Created folder: ./static/data/개인화폴더\A0108
# Created folder: ./static/data/개인화폴더\A0109
# Created folder: ./static/data/개인화폴더\A0110
# Created folder: ./static/data/개인화폴더\A0111
# Created folder: ./static/data/개인화폴더\A0112
# Created folder: ./static/data/개인화폴더\A0113
# Created folder: ./static/data/개인화폴더\A0114
# Created folder: ./static/data/개인화폴더\A0115
# Created folder: ./static/data/개인화폴더\A0116
# Created folder: ./static/data/개인화폴더\A0117
# Created folder: ./static/data/개인화폴더\A0118
# Created folder: ./static/data/개인화폴더\A0119
# Created folder: ./static/data/개인화폴더\A0120
# Created folder: ./static/data/개인화폴더\A0121
# Created folder: ./static/data/개인화폴더\A0122
# Created folder: ./static/data/개인화폴더\A0123
# Created folder: ./static/data/개인화폴더\A0124
# Created folder: ./static/data/개인화폴더\A0125
# Created folder: ./static/data/개인화폴더\A0126
# Created folder: ./static/data/개인화폴더\A0127
# Created folder: ./static/data/개인화폴더\A0128
# Created folder: ./static/data/개인화폴더\A0129
# Created folder: ./static/data/개인화폴더\A0130
# Created folder: ./static/data/개인화폴더\A0131
# Created folder: ./static/data/개인화폴더\A0132
# Created folder: ./static/data/개인화폴더\A0133
# Created folder: ./static/data/개인화폴더\A0134
# Created folder: ./static/data/개인화폴더\A0135
# Created folder: ./static/data/개인화폴더\A0136
# Created folder: ./static/data/개인화폴더\A0137
# Created folder: ./static/data/개인화폴더\A0138
# Created folder: ./static/data/개인화폴더\A0139
# Created folder: ./static/data/개인화폴더\A0140
# Created folder: ./static/data/개인화폴더\A0141
# Created folder: ./static/data/개인화폴더\A0142
# Created folder: ./static/data/개인화폴더\A0143
# Created folder: ./static/data/개인화폴더\A0144
# Created folder: ./static/data/개인화폴더\A0145
# Created folder: ./static/data/개인화폴더\A0146
# Created folder: ./static/data/개인화폴더\A0147
# Created folder: ./static/data/개인화폴더\A0148
# Created folder: ./static/data/개인화폴더\A0149
# Created folder: ./static/data/개인화폴더\A0150
# Created folder: ./static/data/개인화폴더\A0151
# Created folder: ./static/data/개인화폴더\A0152
# Created folder: ./static/data/개인화폴더\A0153
# Created folder: ./static/data/개인화폴더\A0154
# Created folder: ./static/data/개인화폴더\A0155
# Created folder: ./static/data/개인화폴더\A0156
# Created folder: ./static/data/개인화폴더\A0157
# Created folder: ./static/data/개인화폴더\A0158
# Created folder: ./static/data/개인화폴더\A0159
# Created folder: ./static/data/개인화폴더\A0160
# Created folder: ./static/data/개인화폴더\A0161
# Created folder: ./static/data/개인화폴더\A0162
# Created folder: ./static/data/개인화폴더\A0163
# Created folder: ./static/data/개인화폴더\A0164
# Created folder: ./static/data/개인화폴더\A0165
# Created folder: ./static/data/개인화폴더\A0166
# Created folder: ./static/data/개인화폴더\A0167
# Created folder: ./static/data/개인화폴더\A0168
# Created folder: ./static/data/개인화폴더\A0169
# Created folder: ./static/data/개인화폴더\A0170
# Created folder: ./static/data/개인화폴더\A0171
# Created folder: ./static/data/개인화폴더\A0172
# Created folder: ./static/data/개인화폴더\A0173
# Created folder: ./static/data/개인화폴더\A0174
# Created folder: ./static/data/개인화폴더\A0175
# Created folder: ./static/data/개인화폴더\A0176
# Created folder: ./static/data/개인화폴더\A0177
# Created folder: ./static/data/개인화폴더\A0178
# Created folder: ./static/data/개인화폴더\A0179
# Created folder: ./static/data/개인화폴더\A0180
# Created folder: ./static/data/개인화폴더\A0181
# Created folder: ./static/data/개인화폴더\A0182
# Created folder: ./static/data/개인화폴더\A0183
# Created folder: ./static/data/개인화폴더\A0184
# Created folder: ./static/data/개인화폴더\A0185
# Created folder: ./static/data/개인화폴더\A0186
# Created folder: ./static/data/개인화폴더\A0187
# Created folder: ./static/data/개인화폴더\A0188
# Created folder: ./static/data/개인화폴더\A0189
# Created folder: ./static/data/개인화폴더\A0190
# Created folder: ./static/data/개인화폴더\A0191
# Created folder: ./static/data/개인화폴더\A0192
# Created folder: ./static/data/개인화폴더\A0193
# Created folder: ./static/data/개인화폴더\A0194
# Created folder: ./static/data/개인화폴더\A0195
# Created folder: ./static/data/개인화폴더\A0196
# Created folder: ./static/data/개인화폴더\A0197
# Created folder: ./static/data/개인화폴더\A0198
# Created folder: ./static/data/개인화폴더\A0199
# Created folder: ./static/data/개인화폴더\A0200
# Created folder: ./static/data/개인화폴더\A0201
# Created folder: ./static/data/개인화폴더\A0202
# Created folder: ./static/data/개인화폴더\A0203
# Created folder: ./static/data/개인화폴더\A0204
# Created folder: ./static/data/개인화폴더\A0205
# Created folder: ./static/data/개인화폴더\A0206
# Created folder: ./static/data/개인화폴더\A0207
# Created folder: ./static/data/개인화폴더\A0208
# Created folder: ./static/data/개인화폴더\A0209
# Created folder: ./static/data/개인화폴더\A0210
# Created folder: ./static/data/개인화폴더\A0211
# Created folder: ./static/data/개인화폴더\A0212
# Created folder: ./static/data/개인화폴더\A0213
# Created folder: ./static/data/개인화폴더\A0214
# Created folder: ./static/data/개인화폴더\A0215
# Created folder: ./static/data/개인화폴더\A0216
# Created folder: ./static/data/개인화폴더\A0217
# Created folder: ./static/data/개인화폴더\A0218
# Created folder: ./static/data/개인화폴더\A0219
# Created folder: ./static/data/개인화폴더\A0220
# Created folder: ./static/data/개인화폴더\A0221
# Created folder: ./static/data/개인화폴더\A0222
# Created folder: ./static/data/개인화폴더\A0223
# Created folder: ./static/data/개인화폴더\A0224
# Created folder: ./static/data/개인화폴더\A0225
# Created folder: ./static/data/개인화폴더\A0226
# Created folder: ./static/data/개인화폴더\A0227
# Created folder: ./static/data/개인화폴더\A0228
# Created folder: ./static/data/개인화폴더\A0229
# Created folder: ./static/data/개인화폴더\A0230
# Created folder: ./static/data/개인화폴더\A0231
# Created folder: ./static/data/개인화폴더\A0232
# Created folder: ./static/data/개인화폴더\A0233
# Created folder: ./static/data/개인화폴더\A0234
# Created folder: ./static/data/개인화폴더\A0235
# Created folder: ./static/data/개인화폴더\A0236
# Created folder: ./static/data/개인화폴더\A0237
# Created folder: ./static/data/개인화폴더\A0238
# Created folder: ./static/data/개인화폴더\A0239
# Created folder: ./static/data/개인화폴더\A0240
# Created folder: ./static/data/개인화폴더\A0241
# Created folder: ./static/data/개인화폴더\A0242
# Created folder: ./static/data/개인화폴더\A0243
# Created folder: ./static/data/개인화폴더\A0244
# Created folder: ./static/data/개인화폴더\A0245
# Created folder: ./static/data/개인화폴더\A0246
# Created folder: ./static/data/개인화폴더\A0247
# Created folder: ./static/data/개인화폴더\A0248
# Created folder: ./static/data/개인화폴더\A0249
# Created folder: ./static/data/개인화폴더\A0250
# Created folder: ./static/data/개인화폴더\A0251
# Created folder: ./static/data/개인화폴더\A0252
# Created folder: ./static/data/개인화폴더\A0253
# Created folder: ./static/data/개인화폴더\A0254
# Created folder: ./static/data/개인화폴더\A0255
# Created folder: ./static/data/개인화폴더\A0256
# Created folder: ./static/data/개인화폴더\A0257
# Created folder: ./static/data/개인화폴더\A0258
# Created folder: ./static/data/개인화폴더\A0259
# Created folder: ./static/data/개인화폴더\A0260
# Created folder: ./static/data/개인화폴더\A0261
# Created folder: ./static/data/개인화폴더\A0262
# Created folder: ./static/data/개인화폴더\A0263
# Created folder: ./static/data/개인화폴더\A0264
# Created folder: ./static/data/개인화폴더\A0265
# Created folder: ./static/data/개인화폴더\A0266
# Created folder: ./static/data/개인화폴더\A0267
# Created folder: ./static/data/개인화폴더\A0268
# Created folder: ./static/data/개인화폴더\A0269
# Created folder: ./static/data/개인화폴더\A0270
# Created folder: ./static/data/개인화폴더\A0271
# Created folder: ./static/data/개인화폴더\A0272
# Created folder: ./static/data/개인화폴더\A0273
# Created folder: ./static/data/개인화폴더\A0274
# Created folder: ./static/data/개인화폴더\A0275
# Created folder: ./static/data/개인화폴더\A0276
# Created folder: ./static/data/개인화폴더\A0277
# Created folder: ./static/data/개인화폴더\A0278
# Created folder: ./static/data/개인화폴더\A0279
# Created folder: ./static/data/개인화폴더\A0280
# Created folder: ./static/data/개인화폴더\A0281
# Created folder: ./static/data/개인화폴더\A0282
# Created folder: ./static/data/개인화폴더\A0283
# Created folder: ./static/data/개인화폴더\A0284
# Created folder: ./static/data/개인화폴더\A0285
# Created folder: ./static/data/개인화폴더\A0286
# Created folder: ./static/data/개인화폴더\A0287
# Created folder: ./static/data/개인화폴더\A0288
# Created folder: ./static/data/개인화폴더\A0289
# Created folder: ./static/data/개인화폴더\A0290
# Created folder: ./static/data/개인화폴더\A0291
# Created folder: ./static/data/개인화폴더\A0292
# Created folder: ./static/data/개인화폴더\A0293
# Created folder: ./static/data/개인화폴더\A0294
# Created folder: ./static/data/개인화폴더\A0295
# Created folder: ./static/data/개인화폴더\A0296
# Created folder: ./static/data/개인화폴더\A0297
# Created folder: ./static/data/개인화폴더\A0298
# Created folder: ./static/data/개인화폴더\A0299
# Created folder: ./static/data/개인화폴더\A0300
# Created folder: ./static/data/개인화폴더\A0301
# Created folder: ./static/data/개인화폴더\A0302
# Created folder: ./static/data/개인화폴더\A0303
# Created folder: ./static/data/개인화폴더\A0304
# Created folder: ./static/data/개인화폴더\A0305
# Created folder: ./static/data/개인화폴더\A0306
# Created folder: ./static/data/개인화폴더\A0307
# Created folder: ./static/data/개인화폴더\A0308
# Created folder: ./static/data/개인화폴더\A0309
# Created folder: ./static/data/개인화폴더\A0310
# Created folder: ./static/data/개인화폴더\A0311
# Created folder: ./static/data/개인화폴더\A0312
# Created folder: ./static/data/개인화폴더\A0313
# Created folder: ./static/data/개인화폴더\A0314
# Created folder: ./static/data/개인화폴더\A0315
# Created folder: ./static/data/개인화폴더\A0316
# Created folder: ./static/data/개인화폴더\A0317
# Created folder: ./static/data/개인화폴더\A0318
# Created folder: ./static/data/개인화폴더\A0319
# Created folder: ./static/data/개인화폴더\A0320
# Created folder: ./static/data/개인화폴더\A0321
# Created folder: ./static/data/개인화폴더\A0322
# Created folder: ./static/data/개인화폴더\A0323
# Created folder: ./static/data/개인화폴더\A0324
# Created folder: ./static/data/개인화폴더\A0325
# Created folder: ./static/data/개인화폴더\A0326
# Created folder: ./static/data/개인화폴더\A0327
# Created folder: ./static/data/개인화폴더\A0328
# Created folder: ./static/data/개인화폴더\A0329
# Created folder: ./static/data/개인화폴더\A0330
# Created folder: ./static/data/개인화폴더\A0331
# Created folder: ./static/data/개인화폴더\A0332
# Created folder: ./static/data/개인화폴더\A0333
# Created folder: ./static/data/개인화폴더\A0334
# Created folder: ./static/data/개인화폴더\A0335
# Created folder: ./static/data/개인화폴더\A0336
# Created folder: ./static/data/개인화폴더\A0337
# Created folder: ./static/data/개인화폴더\A0338
# Created folder: ./static/data/개인화폴더\A0339
# Created folder: ./static/data/개인화폴더\A0340
# Created folder: ./static/data/개인화폴더\A0341
# Created folder: ./static/data/개인화폴더\A0342
# Created folder: ./static/data/개인화폴더\A0343
# Created folder: ./static/data/개인화폴더\A0344
# Created folder: ./static/data/개인화폴더\A0345
# Created folder: ./static/data/개인화폴더\A0346
# Created folder: ./static/data/개인화폴더\A0347
# Created folder: ./static/data/개인화폴더\A0348
# Created folder: ./static/data/개인화폴더\A0349
# Created folder: ./static/data/개인화폴더\A0350
# Created folder: ./static/data/개인화폴더\A0351
# Created folder: ./static/data/개인화폴더\A0352
# Created folder: ./static/data/개인화폴더\A0353
# Created folder: ./static/data/개인화폴더\A0354
# Created folder: ./static/data/개인화폴더\A0355
# Created folder: ./static/data/개인화폴더\A0356
# Created folder: ./static/data/개인화폴더\A0357
# Created folder: ./static/data/개인화폴더\A0358
# Created folder: ./static/data/개인화폴더\A0359
# Created folder: ./static/data/개인화폴더\A0360
# Created folder: ./static/data/개인화폴더\A0361
# Created folder: ./static/data/개인화폴더\A0362
# Created folder: ./static/data/개인화폴더\A0363
# Created folder: ./static/data/개인화폴더\A0364
# Created folder: ./static/data/개인화폴더\A0365
# Created folder: ./static/data/개인화폴더\A0366
# Created folder: ./static/data/개인화폴더\A0367
# Created folder: ./static/data/개인화폴더\A0368
# Created folder: ./static/data/개인화폴더\A0369
# Created folder: ./static/data/개인화폴더\A0370
# Created folder: ./static/data/개인화폴더\A0371
# Created folder: ./static/data/개인화폴더\A0372
# Created folder: ./static/data/개인화폴더\A0373
# Created folder: ./static/data/개인화폴더\A0374
# Created folder: ./static/data/개인화폴더\A0375
# Created folder: ./static/data/개인화폴더\A0376
# Created folder: ./static/data/개인화폴더\A0377
# Created folder: ./static/data/개인화폴더\A0378
# Created folder: ./static/data/개인화폴더\A0379
# Created folder: ./static/data/개인화폴더\A0380
# Created folder: ./static/data/개인화폴더\A0381
# Created folder: ./static/data/개인화폴더\A0382
# Created folder: ./static/data/개인화폴더\A0383
# Created folder: ./static/data/개인화폴더\A0384
# Created folder: ./static/data/개인화폴더\A0385
# Created folder: ./static/data/개인화폴더\A0386
# Created folder: ./static/data/개인화폴더\A0387
# Created folder: ./static/data/개인화폴더\A0388
# Created folder: ./static/data/개인화폴더\A0389
# Created folder: ./static/data/개인화폴더\A0390
# Created folder: ./static/data/개인화폴더\A0391
# Created folder: ./static/data/개인화폴더\A0392
# Created folder: ./static/data/개인화폴더\A0393
# Created folder: ./static/data/개인화폴더\A0394
# Created folder: ./static/data/개인화폴더\A0395
# Created folder: ./static/data/개인화폴더\A0396
# Created folder: ./static/data/개인화폴더\A0397
# Created folder: ./static/data/개인화폴더\A0398
# Created folder: ./static/data/개인화폴더\A0399
# Created folder: ./static/data/개인화폴더\A0400
# Created folder: ./static/data/개인화폴더\A0401
# Created folder: ./static/data/개인화폴더\A0402
# Created folder: ./static/data/개인화폴더\A0403
# Created folder: ./static/data/개인화폴더\A0404
# Created folder: ./static/data/개인화폴더\A0405
# Created folder: ./static/data/개인화폴더\A0406
# Created folder: ./static/data/개인화폴더\A0407
# Created folder: ./static/data/개인화폴더\A0408
# Created folder: ./static/data/개인화폴더\A0409
# Created folder: ./static/data/개인화폴더\A0410
# Created folder: ./static/data/개인화폴더\A0411
# Created folder: ./static/data/개인화폴더\A0412
# Created folder: ./static/data/개인화폴더\A0413
# Created folder: ./static/data/개인화폴더\A0414
# Created folder: ./static/data/개인화폴더\A0415
# Created folder: ./static/data/개인화폴더\A0416
# Created folder: ./static/data/개인화폴더\A0417
# Created folder: ./static/data/개인화폴더\A0418
# Created folder: ./static/data/개인화폴더\A0419
# Created folder: ./static/data/개인화폴더\A0420
# Created folder: ./static/data/개인화폴더\A0421
# Created folder: ./static/data/개인화폴더\A0422
# Created folder: ./static/data/개인화폴더\A0423
# Created folder: ./static/data/개인화폴더\A0424
# Created folder: ./static/data/개인화폴더\A0425
# Created folder: ./static/data/개인화폴더\A0426
# Created folder: ./static/data/개인화폴더\A0427
# Created folder: ./static/data/개인화폴더\A0428
# Created folder: ./static/data/개인화폴더\A0429
# Created folder: ./static/data/개인화폴더\A0430
# Created folder: ./static/data/개인화폴더\A0431
# Created folder: ./static/data/개인화폴더\A0432
# Created folder: ./static/data/개인화폴더\A0433
# Created folder: ./static/data/개인화폴더\A0434
# Created folder: ./static/data/개인화폴더\A0435
# Created folder: ./static/data/개인화폴더\A0436
# Created folder: ./static/data/개인화폴더\A0437
# Created folder: ./static/data/개인화폴더\A0438
# Created folder: ./static/data/개인화폴더\A0439
# Created folder: ./static/data/개인화폴더\A0440
# Created folder: ./static/data/개인화폴더\A0441
# Created folder: ./static/data/개인화폴더\A0442
# Created folder: ./static/data/개인화폴더\A0443
# Created folder: ./static/data/개인화폴더\A0444
# Created folder: ./static/data/개인화폴더\A0445
# Created folder: ./static/data/개인화폴더\A0446
# Created folder: ./static/data/개인화폴더\A0447
# Created folder: ./static/data/개인화폴더\A0448
# Created folder: ./static/data/개인화폴더\A0449
# Created folder: ./static/data/개인화폴더\A0450
# Created folder: ./static/data/개인화폴더\A0451
# Created folder: ./static/data/개인화폴더\A0452
# Created folder: ./static/data/개인화폴더\A0453
# Created folder: ./static/data/개인화폴더\A0454
# Created folder: ./static/data/개인화폴더\A0455
# Created folder: ./static/data/개인화폴더\A0456
# Created folder: ./static/data/개인화폴더\A0457
# Created folder: ./static/data/개인화폴더\A0458
# Created folder: ./static/data/개인화폴더\A0459
# Created folder: ./static/data/개인화폴더\A0460
# Created folder: ./static/data/개인화폴더\A0461
# Created folder: ./static/data/개인화폴더\A0462
# Created folder: ./static/data/개인화폴더\A0463
# Created folder: ./static/data/개인화폴더\A0464
# Created folder: ./static/data/개인화폴더\A0465
# Created folder: ./static/data/개인화폴더\A0466
# Created folder: ./static/data/개인화폴더\A0467
# Created folder: ./static/data/개인화폴더\A0468
# Created folder: ./static/data/개인화폴더\A0469
# Created folder: ./static/data/개인화폴더\A0470
# Created folder: ./static/data/개인화폴더\A0471
# Created folder: ./static/data/개인화폴더\A0472
# Created folder: ./static/data/개인화폴더\A0473
# Created folder: ./static/data/개인화폴더\A0474
# Created folder: ./static/data/개인화폴더\A0475
# Created folder: ./static/data/개인화폴더\A0476
# Created folder: ./static/data/개인화폴더\A0477
# Created folder: ./static/data/개인화폴더\A0478
# Created folder: ./static/data/개인화폴더\A0479
# Created folder: ./static/data/개인화폴더\A0480
# Created folder: ./static/data/개인화폴더\A0481
# Created folder: ./static/data/개인화폴더\A0482
# Created folder: ./static/data/개인화폴더\A0483
# Created folder: ./static/data/개인화폴더\A0484
# Created folder: ./static/data/개인화폴더\A0485
# Created folder: ./static/data/개인화폴더\A0486
# Created folder: ./static/data/개인화폴더\A0487
# Created folder: ./static/data/개인화폴더\A0488
# Created folder: ./static/data/개인화폴더\A0489
# Created folder: ./static/data/개인화폴더\A0490
# Created folder: ./static/data/개인화폴더\A0491
# Created folder: ./static/data/개인화폴더\A0492
# Created folder: ./static/data/개인화폴더\A0493
# Created folder: ./static/data/개인화폴더\A0494
# Created folder: ./static/data/개인화폴더\A0495
# Created folder: ./static/data/개인화폴더\A0496
# Created folder: ./static/data/개인화폴더\A0497
# Created folder: ./static/data/개인화폴더\A0498
# Created folder: ./static/data/개인화폴더\A0499
# Created folder: ./static/data/개인화폴더\A0500
# Created folder: ./static/data/개인화폴더\A0501
# Created folder: ./static/data/개인화폴더\A0502
# Created folder: ./static/data/개인화폴더\A0503
# Created folder: ./static/data/개인화폴더\A0504
# Created folder: ./static/data/개인화폴더\A0505
# Created folder: ./static/data/개인화폴더\A0506
# Created folder: ./static/data/개인화폴더\A0507
# Created folder: ./static/data/개인화폴더\A0508
# Created folder: ./static/data/개인화폴더\A0509
# Created folder: ./static/data/개인화폴더\A0510
# Created folder: ./static/data/개인화폴더\A0511
# Created folder: ./static/data/개인화폴더\A0512
# Created folder: ./static/data/개인화폴더\A0513
# Created folder: ./static/data/개인화폴더\A0514
# Created folder: ./static/data/개인화폴더\A0515
# Created folder: ./static/data/개인화폴더\A0516
# Created folder: ./static/data/개인화폴더\A0517
# Created folder: ./static/data/개인화폴더\A0518
# Created folder: ./static/data/개인화폴더\A0519
# Created folder: ./static/data/개인화폴더\A0520
# Created folder: ./static/data/개인화폴더\A0521
# Created folder: ./static/data/개인화폴더\A0522
# Created folder: ./static/data/개인화폴더\A0523
# Created folder: ./static/data/개인화폴더\A0524
# Created folder: ./static/data/개인화폴더\A0525
# Created folder: ./static/data/개인화폴더\A0526
# Created folder: ./static/data/개인화폴더\A0527
# Created folder: ./static/data/개인화폴더\A0528
# Created folder: ./static/data/개인화폴더\A0529
# Created folder: ./static/data/개인화폴더\A0530
# Created folder: ./static/data/개인화폴더\A0531
# Created folder: ./static/data/개인화폴더\A0532
# Created folder: ./static/data/개인화폴더\A0533
# Created folder: ./static/data/개인화폴더\A0534
# Created folder: ./static/data/개인화폴더\A0535
# Created folder: ./static/data/개인화폴더\A0536
# Created folder: ./static/data/개인화폴더\A0537
# Created folder: ./static/data/개인화폴더\A0538
# Created folder: ./static/data/개인화폴더\A0539
# Created folder: ./static/data/개인화폴더\A0540
# Created folder: ./static/data/개인화폴더\A0541
# Created folder: ./static/data/개인화폴더\A0542
# Created folder: ./static/data/개인화폴더\A0543
# Created folder: ./static/data/개인화폴더\A0544
# Created folder: ./static/data/개인화폴더\A0545
# Created folder: ./static/data/개인화폴더\A0546
# Created folder: ./static/data/개인화폴더\A0547
# Created folder: ./static/data/개인화폴더\A0548
# Created folder: ./static/data/개인화폴더\A0549
# Created folder: ./static/data/개인화폴더\A0550
# Created folder: ./static/data/개인화폴더\A0551
# Created folder: ./static/data/개인화폴더\A0552
# Created folder: ./static/data/개인화폴더\A0553
# Created folder: ./static/data/개인화폴더\A0554
# Created folder: ./static/data/개인화폴더\A0555
# Created folder: ./static/data/개인화폴더\A0556
# Created folder: ./static/data/개인화폴더\A0557
# Created folder: ./static/data/개인화폴더\A0558
# Created folder: ./static/data/개인화폴더\A0559
# Created folder: ./static/data/개인화폴더\A0560
# Created folder: ./static/data/개인화폴더\A0561
# Created folder: ./static/data/개인화폴더\A0562
# Created folder: ./static/data/개인화폴더\A0563
# Created folder: ./static/data/개인화폴더\A0564
# Created folder: ./static/data/개인화폴더\A0565
# Created folder: ./static/data/개인화폴더\A0566
# Created folder: ./static/data/개인화폴더\A0567
# Created folder: ./static/data/개인화폴더\A0568
# Created folder: ./static/data/개인화폴더\A0569
# Created folder: ./static/data/개인화폴더\A0570
# Created folder: ./static/data/개인화폴더\A0571
# Created folder: ./static/data/개인화폴더\A0572
# Created folder: ./static/data/개인화폴더\A0573
# Created folder: ./static/data/개인화폴더\A0574
# Created folder: ./static/data/개인화폴더\A0575
# Created folder: ./static/data/개인화폴더\A0576
# Created folder: ./static/data/개인화폴더\A0577
# Created folder: ./static/data/개인화폴더\A0578
# Created folder: ./static/data/개인화폴더\A0579
# Created folder: ./static/data/개인화폴더\A0580
# Created folder: ./static/data/개인화폴더\A0581
# Created folder: ./static/data/개인화폴더\A0582
# Created folder: ./static/data/개인화폴더\A0583
# Created folder: ./static/data/개인화폴더\A0584
# Created folder: ./static/data/개인화폴더\A0585
# Created folder: ./static/data/개인화폴더\A0586
# Created folder: ./static/data/개인화폴더\A0587
# Created folder: ./static/data/개인화폴더\A0588
# Created folder: ./static/data/개인화폴더\A0589
# Created folder: ./static/data/개인화폴더\A0590
# Created folder: ./static/data/개인화폴더\A0591
# Created folder: ./static/data/개인화폴더\A0592
# Created folder: ./static/data/개인화폴더\A0593
# Created folder: ./static/data/개인화폴더\A0594
# Created folder: ./static/data/개인화폴더\A0595
# Created folder: ./static/data/개인화폴더\A0596
# Created folder: ./static/data/개인화폴더\A0597
# Created folder: ./static/data/개인화폴더\A0598
# Created folder: ./static/data/개인화폴더\A0599
# Created folder: ./static/data/개인화폴더\A0600
# Created folder: ./static/data/개인화폴더\A0601
# Created folder: ./static/data/개인화폴더\A0602
# Created folder: ./static/data/개인화폴더\A0603
# Created folder: ./static/data/개인화폴더\A0604
# Created folder: ./static/data/개인화폴더\A0605
# Created folder: ./static/data/개인화폴더\A0606
# Created folder: ./static/data/개인화폴더\A0607
# Created folder: ./static/data/개인화폴더\A0608
# Created folder: ./static/data/개인화폴더\A0609
# Created folder: ./static/data/개인화폴더\A0610
# Created folder: ./static/data/개인화폴더\A0611
# Created folder: ./static/data/개인화폴더\A0612
# Created folder: ./static/data/개인화폴더\A0613
# Created folder: ./static/data/개인화폴더\A0614
# Created folder: ./static/data/개인화폴더\A0615
# Created folder: ./static/data/개인화폴더\A0616
# Created folder: ./static/data/개인화폴더\A0617
# Created folder: ./static/data/개인화폴더\A0618
# Created folder: ./static/data/개인화폴더\A0619
# Created folder: ./static/data/개인화폴더\A0620
# Created folder: ./static/data/개인화폴더\A0621
# Created folder: ./static/data/개인화폴더\A0622
# Created folder: ./static/data/개인화폴더\A0623
# Created folder: ./static/data/개인화폴더\A0624
# Created folder: ./static/data/개인화폴더\A0625
# Created folder: ./static/data/개인화폴더\A0626
# Created folder: ./static/data/개인화폴더\A0627
# Created folder: ./static/data/개인화폴더\A0628
# Created folder: ./static/data/개인화폴더\A0629
# Created folder: ./static/data/개인화폴더\A0630
# Created folder: ./static/data/개인화폴더\A0631
# Created folder: ./static/data/개인화폴더\A0632
# Created folder: ./static/data/개인화폴더\A0633
# Created folder: ./static/data/개인화폴더\A0634
# Created folder: ./static/data/개인화폴더\A0635
# Created folder: ./static/data/개인화폴더\A0636
# Created folder: ./static/data/개인화폴더\A0637
# Created folder: ./static/data/개인화폴더\A0638
# Created folder: ./static/data/개인화폴더\A0639
# Created folder: ./static/data/개인화폴더\A0640
# Created folder: ./static/data/개인화폴더\A0641
# Created folder: ./static/data/개인화폴더\A0642
# Created folder: ./static/data/개인화폴더\A0643
# Created folder: ./static/data/개인화폴더\A0644
# Created folder: ./static/data/개인화폴더\A0645
# Created folder: ./static/data/개인화폴더\A0646
# Created folder: ./static/data/개인화폴더\A0647
# Created folder: ./static/data/개인화폴더\A0648
# Created folder: ./static/data/개인화폴더\A0649
# Created folder: ./static/data/개인화폴더\A0650
# Created folder: ./static/data/개인화폴더\A0651
# Created folder: ./static/data/개인화폴더\A0652
# Created folder: ./static/data/개인화폴더\A0653
# Created folder: ./static/data/개인화폴더\A0654
# Created folder: ./static/data/개인화폴더\A0655
# Created folder: ./static/data/개인화폴더\A0656
# Created folder: ./static/data/개인화폴더\A0657
# Created folder: ./static/data/개인화폴더\A0658
# Created folder: ./static/data/개인화폴더\A0659
# Created folder: ./static/data/개인화폴더\A0660
# Created folder: ./static/data/개인화폴더\A0661
# Created folder: ./static/data/개인화폴더\A0662
# Created folder: ./static/data/개인화폴더\A0663
# Created folder: ./static/data/개인화폴더\A0664
# Created folder: ./static/data/개인화폴더\A0665
# Created folder: ./static/data/개인화폴더\A0666
# Created folder: ./static/data/개인화폴더\A0667
# Created folder: ./static/data/개인화폴더\A0668
# Created folder: ./static/data/개인화폴더\A0669
# Created folder: ./static/data/개인화폴더\A0670
# Created folder: ./static/data/개인화폴더\A0671
# Created folder: ./static/data/개인화폴더\A0672
# Created folder: ./static/data/개인화폴더\A0673
# Created folder: ./static/data/개인화폴더\A0674
# Created folder: ./static/data/개인화폴더\A0675
# Created folder: ./static/data/개인화폴더\A0676
# Created folder: ./static/data/개인화폴더\A0677
# Created folder: ./static/data/개인화폴더\A0678
# Created folder: ./static/data/개인화폴더\A0679
# Created folder: ./static/data/개인화폴더\A0680
# Created folder: ./static/data/개인화폴더\A0681
# Created folder: ./static/data/개인화폴더\A0682
# Created folder: ./static/data/개인화폴더\A0683
# Created folder: ./static/data/개인화폴더\A0684
# Created folder: ./static/data/개인화폴더\A0685
# Created folder: ./static/data/개인화폴더\A0686
# Created folder: ./static/data/개인화폴더\A0687
# Created folder: ./static/data/개인화폴더\A0688
# Created folder: ./static/data/개인화폴더\A0689
# Created folder: ./static/data/개인화폴더\A0690
# Created folder: ./static/data/개인화폴더\A0691
# Created folder: ./static/data/개인화폴더\A0692
# Created folder: ./static/data/개인화폴더\A0693
# Created folder: ./static/data/개인화폴더\A0694
# Created folder: ./static/data/개인화폴더\A0695
# Created folder: ./static/data/개인화폴더\A0696
# Created folder: ./static/data/개인화폴더\A0697
# Created folder: ./static/data/개인화폴더\A0698
# Created folder: ./static/data/개인화폴더\A0699
# Created folder: ./static/data/개인화폴더\A0700
# Created folder: ./static/data/개인화폴더\A0701
# Created folder: ./static/data/개인화폴더\A0702
# Created folder: ./static/data/개인화폴더\A0703
# Created folder: ./static/data/개인화폴더\A0704
# Created folder: ./static/data/개인화폴더\A0705
# Created folder: ./static/data/개인화폴더\A0706
# Created folder: ./static/data/개인화폴더\A0707
# Created folder: ./static/data/개인화폴더\A0708
# Created folder: ./static/data/개인화폴더\A0709
# Created folder: ./static/data/개인화폴더\A0710
# Created folder: ./static/data/개인화폴더\A0711
# Created folder: ./static/data/개인화폴더\A0712
# Created folder: ./static/data/개인화폴더\A0713
# Created folder: ./static/data/개인화폴더\A0714
# Created folder: ./static/data/개인화폴더\A0715
# Created folder: ./static/data/개인화폴더\A0716
# Created folder: ./static/data/개인화폴더\A0717
# Created folder: ./static/data/개인화폴더\A0718
# Created folder: ./static/data/개인화폴더\A0719
# Created folder: ./static/data/개인화폴더\A0720
# Created folder: ./static/data/개인화폴더\A0721
# Created folder: ./static/data/개인화폴더\A0722
# Created folder: ./static/data/개인화폴더\A0723
# Created folder: ./static/data/개인화폴더\A0724
# Created folder: ./static/data/개인화폴더\A0725
# Created folder: ./static/data/개인화폴더\A0726
# Created folder: ./static/data/개인화폴더\A0727
# Created folder: ./static/data/개인화폴더\A0728
# Created folder: ./static/data/개인화폴더\A0729
# Created folder: ./static/data/개인화폴더\A0730
# Created folder: ./static/data/개인화폴더\A0731
# Created folder: ./static/data/개인화폴더\A0732
# Created folder: ./static/data/개인화폴더\A0733
# Created folder: ./static/data/개인화폴더\A0734
# Created folder: ./static/data/개인화폴더\A0735
# Created folder: ./static/data/개인화폴더\A0736
# Created folder: ./static/data/개인화폴더\A0737
# Created folder: ./static/data/개인화폴더\A0738
# Created folder: ./static/data/개인화폴더\A0739
# Created folder: ./static/data/개인화폴더\A0740
# Created folder: ./static/data/개인화폴더\A0741
# Created folder: ./static/data/개인화폴더\A0742
# Created folder: ./static/data/개인화폴더\A0743
# Created folder: ./static/data/개인화폴더\A0744
# Created folder: ./static/data/개인화폴더\A0745
# Created folder: ./static/data/개인화폴더\A0746
# Created folder: ./static/data/개인화폴더\A0747
# Created folder: ./static/data/개인화폴더\A0748
# Created folder: ./static/data/개인화폴더\A0749
# Created folder: ./static/data/개인화폴더\A0750
# Created folder: ./static/data/개인화폴더\A0751
# Created folder: ./static/data/개인화폴더\A0752
# Created folder: ./static/data/개인화폴더\A0753
# Created folder: ./static/data/개인화폴더\A0754
# Created folder: ./static/data/개인화폴더\A0755
# Created folder: ./static/data/개인화폴더\A0756
# Created folder: ./static/data/개인화폴더\A0757
# Created folder: ./static/data/개인화폴더\A0758
# Created folder: ./static/data/개인화폴더\A0759
# Created folder: ./static/data/개인화폴더\A0760
# Created folder: ./static/data/개인화폴더\A0761
# Created folder: ./static/data/개인화폴더\A0762
# Created folder: ./static/data/개인화폴더\A0763
# Created folder: ./static/data/개인화폴더\A0764
# Created folder: ./static/data/개인화폴더\A0765
# Created folder: ./static/data/개인화폴더\A0766
# Created folder: ./static/data/개인화폴더\A0767
# Created folder: ./static/data/개인화폴더\A0768
# Created folder: ./static/data/개인화폴더\A0769
# Created folder: ./static/data/개인화폴더\A0770
# Created folder: ./static/data/개인화폴더\A0771
# Created folder: ./static/data/개인화폴더\A0772
# Created folder: ./static/data/개인화폴더\A0773
# Created folder: ./static/data/개인화폴더\A0774
# Created folder: ./static/data/개인화폴더\A0775
# Created folder: ./static/data/개인화폴더\A0776
# Created folder: ./static/data/개인화폴더\A0777
# Created folder: ./static/data/개인화폴더\A0778
# Created folder: ./static/data/개인화폴더\A0779
# Created folder: ./static/data/개인화폴더\A0780
# Created folder: ./static/data/개인화폴더\A0781
# Created folder: ./static/data/개인화폴더\A0782
# Created folder: ./static/data/개인화폴더\A0783
# Created folder: ./static/data/개인화폴더\A0784
# Created folder: ./static/data/개인화폴더\A0785
# Created folder: ./static/data/개인화폴더\A0786
# Created folder: ./static/data/개인화폴더\A0787
# Created folder: ./static/data/개인화폴더\A0788
# Created folder: ./static/data/개인화폴더\A0789
# Created folder: ./static/data/개인화폴더\A0790
# Created folder: ./static/data/개인화폴더\A0791
# Created folder: ./static/data/개인화폴더\A0792
# Created folder: ./static/data/개인화폴더\A0793
# Created folder: ./static/data/개인화폴더\A0794
# Created folder: ./static/data/개인화폴더\A0795
# Created folder: ./static/data/개인화폴더\A0796
# Created folder: ./static/data/개인화폴더\A0797
# Created folder: ./static/data/개인화폴더\A0798
# Created folder: ./static/data/개인화폴더\A0799
# Created folder: ./static/data/개인화폴더\A0800
# Created folder: ./static/data/개인화폴더\A0801
# Created folder: ./static/data/개인화폴더\A0802
# Created folder: ./static/data/개인화폴더\A0803
# Created folder: ./static/data/개인화폴더\A0804
# Created folder: ./static/data/개인화폴더\A0805
# Created folder: ./static/data/개인화폴더\A0806
# Created folder: ./static/data/개인화폴더\A0807
# Created folder: ./static/data/개인화폴더\A0808
# Created folder: ./static/data/개인화폴더\A0809
# Created folder: ./static/data/개인화폴더\A0810
# Created folder: ./static/data/개인화폴더\A0811
# Created folder: ./static/data/개인화폴더\A0812
# Created folder: ./static/data/개인화폴더\A0813
# Created folder: ./static/data/개인화폴더\A0814
# Created folder: ./static/data/개인화폴더\A0815
# Created folder: ./static/data/개인화폴더\A0816
# Created folder: ./static/data/개인화폴더\A0817
# Created folder: ./static/data/개인화폴더\A0818
# Created folder: ./static/data/개인화폴더\A0819
# Created folder: ./static/data/개인화폴더\A0820
# Created folder: ./static/data/개인화폴더\A0821
# Created folder: ./static/data/개인화폴더\A0822
# Created folder: ./static/data/개인화폴더\A0823
# Created folder: ./static/data/개인화폴더\A0824
# Created folder: ./static/data/개인화폴더\A0825
# Created folder: ./static/data/개인화폴더\A0826
# Created folder: ./static/data/개인화폴더\A0827
# Created folder: ./static/data/개인화폴더\A0828
# Created folder: ./static/data/개인화폴더\A0829
# Created folder: ./static/data/개인화폴더\A0830
# Created folder: ./static/data/개인화폴더\A0831
# Created folder: ./static/data/개인화폴더\A0832
# Created folder: ./static/data/개인화폴더\A0833
# Created folder: ./static/data/개인화폴더\A0834
# Created folder: ./static/data/개인화폴더\A0835
# Created folder: ./static/data/개인화폴더\A0836
# Created folder: ./static/data/개인화폴더\A0837
# Created folder: ./static/data/개인화폴더\A0838
# Created folder: ./static/data/개인화폴더\A0839
# Created folder: ./static/data/개인화폴더\A0840
# Created folder: ./static/data/개인화폴더\A0841
# Created folder: ./static/data/개인화폴더\A0842
# Created folder: ./static/data/개인화폴더\A0843
# Created folder: ./static/data/개인화폴더\A0844
# Created folder: ./static/data/개인화폴더\A0845
# Created folder: ./static/data/개인화폴더\A0846
# Created folder: ./static/data/개인화폴더\A0847
# Created folder: ./static/data/개인화폴더\A0848
# Created folder: ./static/data/개인화폴더\A0849
# Created folder: ./static/data/개인화폴더\A0850
# Created folder: ./static/data/개인화폴더\A0851
# Created folder: ./static/data/개인화폴더\A0852
# Created folder: ./static/data/개인화폴더\A0853
# Created folder: ./static/data/개인화폴더\A0854
# Created folder: ./static/data/개인화폴더\A0855
# Created folder: ./static/data/개인화폴더\A0856
# Created folder: ./static/data/개인화폴더\A0857
# Created folder: ./static/data/개인화폴더\A0858
# Created folder: ./static/data/개인화폴더\A0859
# Created folder: ./static/data/개인화폴더\A0860
# Created folder: ./static/data/개인화폴더\A0861
# Created folder: ./static/data/개인화폴더\A0862
# Created folder: ./static/data/개인화폴더\A0863
# Created folder: ./static/data/개인화폴더\A0864
# Created folder: ./static/data/개인화폴더\A0865
# Created folder: ./static/data/개인화폴더\A0866
# Created folder: ./static/data/개인화폴더\A0867
# Created folder: ./static/data/개인화폴더\A0868
# Created folder: ./static/data/개인화폴더\A0869
# Created folder: ./static/data/개인화폴더\A0870
# Created folder: ./static/data/개인화폴더\A0871
# Created folder: ./static/data/개인화폴더\A0872
# Created folder: ./static/data/개인화폴더\A0873
# Created folder: ./static/data/개인화폴더\A0874
# Created folder: ./static/data/개인화폴더\A0875
# Created folder: ./static/data/개인화폴더\A0876
# Created folder: ./static/data/개인화폴더\A0877
# Created folder: ./static/data/개인화폴더\A0878
# Created folder: ./static/data/개인화폴더\A0879
# Created folder: ./static/data/개인화폴더\A0880
# Created folder: ./static/data/개인화폴더\A0881
# Created folder: ./static/data/개인화폴더\A0882
# Created folder: ./static/data/개인화폴더\A0883
# Created folder: ./static/data/개인화폴더\A0884
# Created folder: ./static/data/개인화폴더\A0885
# Created folder: ./static/data/개인화폴더\A0886
# Created folder: ./static/data/개인화폴더\A0887
# Created folder: ./static/data/개인화폴더\A0888
# Created folder: ./static/data/개인화폴더\A0889
# Created folder: ./static/data/개인화폴더\A0890
# Created folder: ./static/data/개인화폴더\A0891
# Created folder: ./static/data/개인화폴더\A0892
# Created folder: ./static/data/개인화폴더\A0893
# Created folder: ./static/data/개인화폴더\A0894
# Created folder: ./static/data/개인화폴더\A0895
# Created folder: ./static/data/개인화폴더\A0896
# Created folder: ./static/data/개인화폴더\A0897
# Created folder: ./static/data/개인화폴더\A0898
# Created folder: ./static/data/개인화폴더\A0899
# Created folder: ./static/data/개인화폴더\A0900
# Created folder: ./static/data/개인화폴더\A0901
# Created folder: ./static/data/개인화폴더\A0902
# Created folder: ./static/data/개인화폴더\A0903
# Created folder: ./static/data/개인화폴더\A0904
# Created folder: ./static/data/개인화폴더\A0905
# Created folder: ./static/data/개인화폴더\A0906
# Created folder: ./static/data/개인화폴더\A0907
# Created folder: ./static/data/개인화폴더\A0908
# Created folder: ./static/data/개인화폴더\A0909
# Created folder: ./static/data/개인화폴더\A0910
# Created folder: ./static/data/개인화폴더\A0911
# Created folder: ./static/data/개인화폴더\A0912
# Created folder: ./static/data/개인화폴더\A0913
# Created folder: ./static/data/개인화폴더\A0914
# Created folder: ./static/data/개인화폴더\A0915
# Created folder: ./static/data/개인화폴더\A0916
# Created folder: ./static/data/개인화폴더\A0917
# Created folder: ./static/data/개인화폴더\A0918
# Created folder: ./static/data/개인화폴더\A0919
# Created folder: ./static/data/개인화폴더\A0920
# Created folder: ./static/data/개인화폴더\A0921
# Created folder: ./static/data/개인화폴더\A0922
# Created folder: ./static/data/개인화폴더\A0923
# Created folder: ./static/data/개인화폴더\A0924
# Created folder: ./static/data/개인화폴더\A0925
# Created folder: ./static/data/개인화폴더\A0926
# Created folder: ./static/data/개인화폴더\A0927
# Created folder: ./static/data/개인화폴더\A0928
# Created folder: ./static/data/개인화폴더\A0929
# Created folder: ./static/data/개인화폴더\A0930
# Created folder: ./static/data/개인화폴더\A0931
# Created folder: ./static/data/개인화폴더\A0932
# Created folder: ./static/data/개인화폴더\A0933
# Created folder: ./static/data/개인화폴더\A0934
# Created folder: ./static/data/개인화폴더\A0935
# Created folder: ./static/data/개인화폴더\A0936
# Created folder: ./static/data/개인화폴더\A0937
# Created folder: ./static/data/개인화폴더\A0938
# Created folder: ./static/data/개인화폴더\A0939
# Created folder: ./static/data/개인화폴더\A0940
# Created folder: ./static/data/개인화폴더\A0941
# Created folder: ./static/data/개인화폴더\A0942
# Created folder: ./static/data/개인화폴더\A0943
# Created folder: ./static/data/개인화폴더\A0944
# Created folder: ./static/data/개인화폴더\A0945
# Created folder: ./static/data/개인화폴더\A0946
# Created folder: ./static/data/개인화폴더\A0947
# Created folder: ./static/data/개인화폴더\A0948
# Created folder: ./static/data/개인화폴더\A0949
# Created folder: ./static/data/개인화폴더\A0950
# Created folder: ./static/data/개인화폴더\A0951
# Created folder: ./static/data/개인화폴더\A0952
# Created folder: ./static/data/개인화폴더\A0953
# Created folder: ./static/data/개인화폴더\A0954
# Created folder: ./static/data/개인화폴더\A0955
# Created folder: ./static/data/개인화폴더\A0956
# Created folder: ./static/data/개인화폴더\A0957
# Created folder: ./static/data/개인화폴더\A0958
# Created folder: ./static/data/개인화폴더\A0959
# Created folder: ./static/data/개인화폴더\A0960
# Created folder: ./static/data/개인화폴더\A0961
# Created folder: ./static/data/개인화폴더\A0962
# Created folder: ./static/data/개인화폴더\A0963
# Created folder: ./static/data/개인화폴더\A0964
# Created folder: ./static/data/개인화폴더\A0965
# Created folder: ./static/data/개인화폴더\A0966
# Created folder: ./static/data/개인화폴더\A0967
# Created folder: ./static/data/개인화폴더\A0968
# Created folder: ./static/data/개인화폴더\A0969
# Created folder: ./static/data/개인화폴더\A0970
# Created folder: ./static/data/개인화폴더\A0971
# Created folder: ./static/data/개인화폴더\A0972
# Created folder: ./static/data/개인화폴더\A0973
# Created folder: ./static/data/개인화폴더\A0974
# Created folder: ./static/data/개인화폴더\A0975
# Created folder: ./static/data/개인화폴더\A0976
# Created folder: ./static/data/개인화폴더\A0977
# Created folder: ./static/data/개인화폴더\A0978
# Created folder: ./static/data/개인화폴더\A0979
# Created folder: ./static/data/개인화폴더\A0980
# Created folder: ./static/data/개인화폴더\A0981
# Created folder: ./static/data/개인화폴더\A0982
# Created folder: ./static/data/개인화폴더\A0983
# Created folder: ./static/data/개인화폴더\A0984
# Created folder: ./static/data/개인화폴더\A0985
# Created folder: ./static/data/개인화폴더\A0986
# Created folder: ./static/data/개인화폴더\A0987
# Created folder: ./static/data/개인화폴더\A0988
# Created folder: ./static/data/개인화폴더\A0989
# Created folder: ./static/data/개인화폴더\A0990
# Created folder: ./static/data/개인화폴더\A0991
# Created folder: ./static/data/개인화폴더\A0992
# Created folder: ./static/data/개인화폴더\A0993
# Created folder: ./static/data/개인화폴더\A0994
# Created folder: ./static/data/개인화폴더\A0995
# Created folder: ./static/data/개인화폴더\A0996
# Created folder: ./static/data/개인화폴더\A0997
# Created folder: ./static/data/개인화폴더\A0998
# Created folder: ./static/data/개인화폴더\A0999
# Created folder: ./static/data/개인화폴더\A1000
# Created folder: ./static/data/개인화폴더\A1001
# Created folder: ./static/data/개인화폴더\A1002
# Created folder: ./static/data/개인화폴더\A1003
# Created folder: ./static/data/개인화폴더\A1004
# Created folder: ./static/data/개인화폴더\A1005
# Created folder: ./static/data/개인화폴더\A1006
# Created folder: ./static/data/개인화폴더\A1007
# Created folder: ./static/data/개인화폴더\A1008
# Created folder: ./static/data/개인화폴더\A1009
# Created folder: ./static/data/개인화폴더\A1010
# Created folder: ./static/data/개인화폴더\A1011
# Created folder: ./static/data/개인화폴더\A1012
# Created folder: ./static/data/개인화폴더\A1013
# Created folder: ./static/data/개인화폴더\A1014
# Created folder: ./static/data/개인화폴더\A1015
# Created folder: ./static/data/개인화폴더\A1016
# Created folder: ./static/data/개인화폴더\A1017
# Created folder: ./static/data/개인화폴더\A1018
# Created folder: ./static/data/개인화폴더\A1019
# Created folder: ./static/data/개인화폴더\A1020
# Created folder: ./static/data/개인화폴더\A1021
# Created folder: ./static/data/개인화폴더\A1022
# Created folder: ./static/data/개인화폴더\A1023
# Created folder: ./static/data/개인화폴더\A1024
# Created folder: ./static/data/개인화폴더\A1025
# Created folder: ./static/data/개인화폴더\A1026
# Created folder: ./static/data/개인화폴더\A1027
# Created folder: ./static/data/개인화폴더\A1028
# Created folder: ./static/data/개인화폴더\A1029
# Created folder: ./static/data/개인화폴더\A1030
# Created folder: ./static/data/개인화폴더\A1031
# Created folder: ./static/data/개인화폴더\A1032
# Created folder: ./static/data/개인화폴더\A1033
# Created folder: ./static/data/개인화폴더\A1034
# Created folder: ./static/data/개인화폴더\A1035
# Created folder: ./static/data/개인화폴더\A1036
# Created folder: ./static/data/개인화폴더\A1037
# Created folder: ./static/data/개인화폴더\A1038
# Created folder: ./static/data/개인화폴더\A1039
# Created folder: ./static/data/개인화폴더\A1040
# Created folder: ./static/data/개인화폴더\A1041
# Created folder: ./static/data/개인화폴더\A1042
# Created folder: ./static/data/개인화폴더\A1043
# Created folder: ./static/data/개인화폴더\A1044
# Created folder: ./static/data/개인화폴더\A1045
# Created folder: ./static/data/개인화폴더\A1046
# Created folder: ./static/data/개인화폴더\A1047
# Created folder: ./static/data/개인화폴더\A1048
# Created folder: ./static/data/개인화폴더\A1049
# Created folder: ./static/data/개인화폴더\A1050
# Created folder: ./static/data/개인화폴더\A1051
# Created folder: ./static/data/개인화폴더\A1052
# Created folder: ./static/data/개인화폴더\A1053
# Created folder: ./static/data/개인화폴더\A1054
# Created folder: ./static/data/개인화폴더\A1055
# Created folder: ./static/data/개인화폴더\A1056
# Created folder: ./static/data/개인화폴더\A1057
# Created folder: ./static/data/개인화폴더\A1058
# Created folder: ./static/data/개인화폴더\A1059
# Created folder: ./static/data/개인화폴더\A1060
# Created folder: ./static/data/개인화폴더\A1061
# Created folder: ./static/data/개인화폴더\A1062
# Created folder: ./static/data/개인화폴더\A1063
# Created folder: ./static/data/개인화폴더\A1064
# Created folder: ./static/data/개인화폴더\A1065
# Created folder: ./static/data/개인화폴더\A1066
# Created folder: ./static/data/개인화폴더\A1067
# Created folder: ./static/data/개인화폴더\A1068
# Created folder: ./static/data/개인화폴더\A1069
# Created folder: ./static/data/개인화폴더\A1070
# Created folder: ./static/data/개인화폴더\A1071
# Created folder: ./static/data/개인화폴더\A1072
# Created folder: ./static/data/개인화폴더\A1073
# Created folder: ./static/data/개인화폴더\A1074
# Created folder: ./static/data/개인화폴더\A1075
# Created folder: ./static/data/개인화폴더\A1076
# Created folder: ./static/data/개인화폴더\A1077
# Created folder: ./static/data/개인화폴더\A1078
# Created folder: ./static/data/개인화폴더\A1079
# Created folder: ./static/data/개인화폴더\A1080
# Created folder: ./static/data/개인화폴더\A1081
# Created folder: ./static/data/개인화폴더\A1082
# Created folder: ./static/data/개인화폴더\A1083
# Created folder: ./static/data/개인화폴더\A1084
# Created folder: ./static/data/개인화폴더\A1085
# Created folder: ./static/data/개인화폴더\A1086
# Created folder: ./static/data/개인화폴더\A1087
# Created folder: ./static/data/개인화폴더\A1088
# Created folder: ./static/data/개인화폴더\A1089
# Created folder: ./static/data/개인화폴더\A1090
# Created folder: ./static/data/개인화폴더\A1091
# Created folder: ./static/data/개인화폴더\A1092
# Created folder: ./static/data/개인화폴더\A1093
# Created folder: ./static/data/개인화폴더\A1094
# Created folder: ./static/data/개인화폴더\A1095
# Created folder: ./static/data/개인화폴더\A1096
# Created folder: ./static/data/개인화폴더\A1097
# Created folder: ./static/data/개인화폴더\A1098
# Created folder: ./static/data/개인화폴더\A1099
# Created folder: ./static/data/개인화폴더\A1100
# Created folder: ./static/data/개인화폴더\A1101
# Created folder: ./static/data/개인화폴더\A1102
# Created folder: ./static/data/개인화폴더\A1103
# Created folder: ./static/data/개인화폴더\A1104
# Created folder: ./static/data/개인화폴더\A1105
# Created folder: ./static/data/개인화폴더\A1106
# Created folder: ./static/data/개인화폴더\A1107
# Created folder: ./static/data/개인화폴더\A1108
# Created folder: ./static/data/개인화폴더\A1109
# Created folder: ./static/data/개인화폴더\A1110
# Created folder: ./static/data/개인화폴더\A1111
# Created folder: ./static/data/개인화폴더\A1112
# Created folder: ./static/data/개인화폴더\A1113
# Created folder: ./static/data/개인화폴더\A1114
# Created folder: ./static/data/개인화폴더\A1115
# Created folder: ./static/data/개인화폴더\A1116
# Created folder: ./static/data/개인화폴더\A1117
# Created folder: ./static/data/개인화폴더\A1118
# Created folder: ./static/data/개인화폴더\A1119
# Created folder: ./static/data/개인화폴더\A1120
# Created folder: ./static/data/개인화폴더\A1121
# Created folder: ./static/data/개인화폴더\A1122
# Created folder: ./static/data/개인화폴더\A1123
# Created folder: ./static/data/개인화폴더\A1124
# Created folder: ./static/data/개인화폴더\A1125
# Created folder: ./static/data/개인화폴더\A1126
# Created folder: ./static/data/개인화폴더\A1127
# Created folder: ./static/data/개인화폴더\A1128
# Created folder: ./static/data/개인화폴더\A1129
# Created folder: ./static/data/개인화폴더\A1130
# Created folder: ./static/data/개인화폴더\A1131
# Created folder: ./static/data/개인화폴더\A1132
# Created folder: ./static/data/개인화폴더\A1133
# Created folder: ./static/data/개인화폴더\A1134
# Created folder: ./static/data/개인화폴더\A1135
# Created folder: ./static/data/개인화폴더\A1136
# Created folder: ./static/data/개인화폴더\A1137
# Created folder: ./static/data/개인화폴더\A1138
# Created folder: ./static/data/개인화폴더\A1139
# Created folder: ./static/data/개인화폴더\A1140
# Created folder: ./static/data/개인화폴더\A1141
# Created folder: ./static/data/개인화폴더\A1142
# ...
# Created folder: ./static/data/개인화폴더\A9620
# Created folder: ./static/data/개인화폴더\A9621
# Created folder: ./static/data/개인화폴더\A9622
# Created folder: ./static/data/개인화폴더\A9623
# Created folder: ./static/data/개인화폴더\A9624
# Created folder: ./static/data/개인화폴더\A9625
# Created folder: ./static/data/개인화폴더\A9626
# Created folder: ./static/data/개인화폴더\A9627
# Created folder: ./static/data/개인화폴더\A9628
# Created folder: ./static/data/개인화폴더\A9629
# Created folder: ./static/data/개인화폴더\A9630
# Created folder: ./static/data/개인화폴더\A9631
# Created folder: ./static/data/개인화폴더\A9632
# Created folder: ./static/data/개인화폴더\A9633
# Created folder: ./static/data/개인화폴더\A9634
# Created folder: ./static/data/개인화폴더\A9635
# Created folder: ./static/data/개인화폴더\A9636
# Created folder: ./static/data/개인화폴더\A9637
# Created folder: ./static/data/개인화폴더\A9638
# Created folder: ./static/data/개인화폴더\A9639
# Created folder: ./static/data/개인화폴더\A9640
# Created folder: ./static/data/개인화폴더\A9641
# Created folder: ./static/data/개인화폴더\A9642
# Created folder: ./static/data/개인화폴더\A9643
# Created folder: ./static/data/개인화폴더\A9644
# Created folder: ./static/data/개인화폴더\A9645
# Created folder: ./static/data/개인화폴더\A9646
# Created folder: ./static/data/개인화폴더\A9647
# Created folder: ./static/data/개인화폴더\A9648
# Created folder: ./static/data/개인화폴더\A9649
# Created folder: ./static/data/개인화폴더\A9650
# Created folder: ./static/data/개인화폴더\A9651
# Created folder: ./static/data/개인화폴더\A9652
# Created folder: ./static/data/개인화폴더\A9653
# Created folder: ./static/data/개인화폴더\A9654
# Created folder: ./static/data/개인화폴더\A9655
# Created folder: ./static/data/개인화폴더\A9656
# Created folder: ./static/data/개인화폴더\A9657
# Created folder: ./static/data/개인화폴더\A9658
# Created folder: ./static/data/개인화폴더\A9659
# Created folder: ./static/data/개인화폴더\A9660
# Created folder: ./static/data/개인화폴더\A9661
# Created folder: ./static/data/개인화폴더\A9662
# Created folder: ./static/data/개인화폴더\A9663
# Created folder: ./static/data/개인화폴더\A9664
# Created folder: ./static/data/개인화폴더\A9665
# Created folder: ./static/data/개인화폴더\A9666
# Created folder: ./static/data/개인화폴더\A9667
# Created folder: ./static/data/개인화폴더\A9668
# Created folder: ./static/data/개인화폴더\A9669
# Created folder: ./static/data/개인화폴더\A9670
# Created folder: ./static/data/개인화폴더\A9671
# Created folder: ./static/data/개인화폴더\A9672
# Created folder: ./static/data/개인화폴더\A9673
# Created folder: ./static/data/개인화폴더\A9674
# Created folder: ./static/data/개인화폴더\A9675
# Created folder: ./static/data/개인화폴더\A9676
# Created folder: ./static/data/개인화폴더\A9677
# Created folder: ./static/data/개인화폴더\A9678
# Created folder: ./static/data/개인화폴더\A9679
# Created folder: ./static/data/개인화폴더\A9680
# Created folder: ./static/data/개인화폴더\A9681
# Created folder: ./static/data/개인화폴더\A9682
# Created folder: ./static/data/개인화폴더\A9683
# Created folder: ./static/data/개인화폴더\A9684
# Created folder: ./static/data/개인화폴더\A9685
# Created folder: ./static/data/개인화폴더\A9686
# Created folder: ./static/data/개인화폴더\A9687
# Created folder: ./static/data/개인화폴더\A9688
# Created folder: ./static/data/개인화폴더\A9689
# Created folder: ./static/data/개인화폴더\A9690
# Created folder: ./static/data/개인화폴더\A9691
# Created folder: ./static/data/개인화폴더\A9692
# Created folder: ./static/data/개인화폴더\A9693
# Created folder: ./static/data/개인화폴더\A9694
# Created folder: ./static/data/개인화폴더\A9695
# Created folder: ./static/data/개인화폴더\A9696
# Created folder: ./static/data/개인화폴더\A9697
# Created folder: ./static/data/개인화폴더\A9698
# Created folder: ./static/data/개인화폴더\A9699
# Created folder: ./static/data/개인화폴더\A9700
# Created folder: ./static/data/개인화폴더\A9701
# Created folder: ./static/data/개인화폴더\A9702
# Created folder: ./static/data/개인화폴더\A9703
# Created folder: ./static/data/개인화폴더\A9704
# Created folder: ./static/data/개인화폴더\A9705
# Created folder: ./static/data/개인화폴더\A9706
# Created folder: ./static/data/개인화폴더\A9707
# Created folder: ./static/data/개인화폴더\A9708
# Created folder: ./static/data/개인화폴더\A9709
# Created folder: ./static/data/개인화폴더\A9710
# Created folder: ./static/data/개인화폴더\A9711
# Created folder: ./static/data/개인화폴더\A9712
# Created folder: ./static/data/개인화폴더\A9713
# Created folder: ./static/data/개인화폴더\A9714
# Created folder: ./static/data/개인화폴더\A9715
# Created folder: ./static/data/개인화폴더\A9716
# Created folder: ./static/data/개인화폴더\A9717
# Created folder: ./static/data/개인화폴더\A9718
# Created folder: ./static/data/개인화폴더\A9719
# Created folder: ./static/data/개인화폴더\A9720
# Created folder: ./static/data/개인화폴더\A9721
# Created folder: ./static/data/개인화폴더\A9722
# Created folder: ./static/data/개인화폴더\A9723
# Created folder: ./static/data/개인화폴더\A9724
# Created folder: ./static/data/개인화폴더\A9725
# Created folder: ./static/data/개인화폴더\A9726
# Created folder: ./static/data/개인화폴더\A9727
# Created folder: ./static/data/개인화폴더\A9728
# Created folder: ./static/data/개인화폴더\A9729
# Created folder: ./static/data/개인화폴더\A9730
# Created folder: ./static/data/개인화폴더\A9731
# Created folder: ./static/data/개인화폴더\A9732
# Created folder: ./static/data/개인화폴더\A9733
# Created folder: ./static/data/개인화폴더\A9734
# Created folder: ./static/data/개인화폴더\A9735
# Created folder: ./static/data/개인화폴더\A9736
# Created folder: ./static/data/개인화폴더\A9737
# Created folder: ./static/data/개인화폴더\A9738
# Created folder: ./static/data/개인화폴더\A9739
# Created folder: ./static/data/개인화폴더\A9740
# Created folder: ./static/data/개인화폴더\A9741
# Created folder: ./static/data/개인화폴더\A9742
# Created folder: ./static/data/개인화폴더\A9743
# Created folder: ./static/data/개인화폴더\A9744
# Created folder: ./static/data/개인화폴더\A9745
# Created folder: ./static/data/개인화폴더\A9746
# Created folder: ./static/data/개인화폴더\A9747
# Created folder: ./static/data/개인화폴더\A9748
# Created folder: ./static/data/개인화폴더\A9749
# Created folder: ./static/data/개인화폴더\A9750
# Created folder: ./static/data/개인화폴더\A9751
# Created folder: ./static/data/개인화폴더\A9752
# Created folder: ./static/data/개인화폴더\A9753
# Created folder: ./static/data/개인화폴더\A9754
# Created folder: ./static/data/개인화폴더\A9755
# Created folder: ./static/data/개인화폴더\A9756
# Created folder: ./static/data/개인화폴더\A9757
# Created folder: ./static/data/개인화폴더\A9758
# Created folder: ./static/data/개인화폴더\A9759
# Created folder: ./static/data/개인화폴더\A9760
# Created folder: ./static/data/개인화폴더\A9761
# Created folder: ./static/data/개인화폴더\A9762
# Created folder: ./static/data/개인화폴더\A9763
# Created folder: ./static/data/개인화폴더\A9764
# Created folder: ./static/data/개인화폴더\A9765
# Created folder: ./static/data/개인화폴더\A9766
# Created folder: ./static/data/개인화폴더\A9767
# Created folder: ./static/data/개인화폴더\A9768
# Created folder: ./static/data/개인화폴더\A9769
# Created folder: ./static/data/개인화폴더\A9770
# Created folder: ./static/data/개인화폴더\A9771
# Created folder: ./static/data/개인화폴더\A9772
# Created folder: ./static/data/개인화폴더\A9773
# Created folder: ./static/data/개인화폴더\A9774
# Created folder: ./static/data/개인화폴더\A9775
# Created folder: ./static/data/개인화폴더\A9776
# Created folder: ./static/data/개인화폴더\A9777
# Created folder: ./static/data/개인화폴더\A9778
# Created folder: ./static/data/개인화폴더\A9779
# Created folder: ./static/data/개인화폴더\A9780
# Created folder: ./static/data/개인화폴더\A9781
# Created folder: ./static/data/개인화폴더\A9782
# Created folder: ./static/data/개인화폴더\A9783
# Created folder: ./static/data/개인화폴더\A9784
# Created folder: ./static/data/개인화폴더\A9785
# Created folder: ./static/data/개인화폴더\A9786
# Created folder: ./static/data/개인화폴더\A9787
# Created folder: ./static/data/개인화폴더\A9788
# Created folder: ./static/data/개인화폴더\A9789
# Created folder: ./static/data/개인화폴더\A9790
# Created folder: ./static/data/개인화폴더\A9791
# Created folder: ./static/data/개인화폴더\A9792
# Created folder: ./static/data/개인화폴더\A9793
# Created folder: ./static/data/개인화폴더\A9794
# Created folder: ./static/data/개인화폴더\A9795
# Created folder: ./static/data/개인화폴더\A9796
# Created folder: ./static/data/개인화폴더\A9797
# Created folder: ./static/data/개인화폴더\A9798
# Created folder: ./static/data/개인화폴더\A9799
# Created folder: ./static/data/개인화폴더\A9800
# Created folder: ./static/data/개인화폴더\A9801
# Created folder: ./static/data/개인화폴더\A9802
# Created folder: ./static/data/개인화폴더\A9803
# Created folder: ./static/data/개인화폴더\A9804
# Created folder: ./static/data/개인화폴더\A9805
# Created folder: ./static/data/개인화폴더\A9806
# Created folder: ./static/data/개인화폴더\A9807
# Created folder: ./static/data/개인화폴더\A9808
# Created folder: ./static/data/개인화폴더\A9809
# Created folder: ./static/data/개인화폴더\A9810
# Created folder: ./static/data/개인화폴더\A9811
# Created folder: ./static/data/개인화폴더\A9812
# Created folder: ./static/data/개인화폴더\A9813
# Created folder: ./static/data/개인화폴더\A9814
# Created folder: ./static/data/개인화폴더\A9815
# Created folder: ./static/data/개인화폴더\A9816
# Created folder: ./static/data/개인화폴더\A9817
# Created folder: ./static/data/개인화폴더\A9818
# Created folder: ./static/data/개인화폴더\A9819
# Created folder: ./static/data/개인화폴더\A9820
# Created folder: ./static/data/개인화폴더\A9821
# Created folder: ./static/data/개인화폴더\A9822
# Created folder: ./static/data/개인화폴더\A9823
# Created folder: ./static/data/개인화폴더\A9824
# Created folder: ./static/data/개인화폴더\A9825
# Created folder: ./static/data/개인화폴더\A9826
# Created folder: ./static/data/개인화폴더\A9827
# Created folder: ./static/data/개인화폴더\A9828
# Created folder: ./static/data/개인화폴더\A9829
# Created folder: ./static/data/개인화폴더\A9830
# Created folder: ./static/data/개인화폴더\A9831
# Created folder: ./static/data/개인화폴더\A9832
# Created folder: ./static/data/개인화폴더\A9833
# Created folder: ./static/data/개인화폴더\A9834
# Created folder: ./static/data/개인화폴더\A9835
# Created folder: ./static/data/개인화폴더\A9836
# Created folder: ./static/data/개인화폴더\A9837
# Created folder: ./static/data/개인화폴더\A9838
# Created folder: ./static/data/개인화폴더\A9839
# Created folder: ./static/data/개인화폴더\A9840
# Created folder: ./static/data/개인화폴더\A9841
# Created folder: ./static/data/개인화폴더\A9842
# Created folder: ./static/data/개인화폴더\A9843
# Created folder: ./static/data/개인화폴더\A9844
# Created folder: ./static/data/개인화폴더\A9845
# Created folder: ./static/data/개인화폴더\A9846
# Created folder: ./static/data/개인화폴더\A9847
# Created folder: ./static/data/개인화폴더\A9848
# Created folder: ./static/data/개인화폴더\A9849
# Created folder: ./static/data/개인화폴더\A9850
# Created folder: ./static/data/개인화폴더\A9851
# Created folder: ./static/data/개인화폴더\A9852
# Created folder: ./static/data/개인화폴더\A9853
# Created folder: ./static/data/개인화폴더\A9854
# Created folder: ./static/data/개인화폴더\A9855
# Created folder: ./static/data/개인화폴더\A9856
# Created folder: ./static/data/개인화폴더\A9857
# Created folder: ./static/data/개인화폴더\A9858
# Created folder: ./static/data/개인화폴더\A9859
# Created folder: ./static/data/개인화폴더\A9860
# Created folder: ./static/data/개인화폴더\A9861
# Created folder: ./static/data/개인화폴더\A9862
# Created folder: ./static/data/개인화폴더\A9863
# Created folder: ./static/data/개인화폴더\A9864
# Created folder: ./static/data/개인화폴더\A9865
# Created folder: ./static/data/개인화폴더\A9866
# Created folder: ./static/data/개인화폴더\A9867
# Created folder: ./static/data/개인화폴더\A9868
# Created folder: ./static/data/개인화폴더\A9869
# Created folder: ./static/data/개인화폴더\A9870
# Created folder: ./static/data/개인화폴더\A9871
# Created folder: ./static/data/개인화폴더\A9872
# Created folder: ./static/data/개인화폴더\A9873
# Created folder: ./static/data/개인화폴더\A9874
# Created folder: ./static/data/개인화폴더\A9875
# Created folder: ./static/data/개인화폴더\A9876
# Created folder: ./static/data/개인화폴더\A9877
# Created folder: ./static/data/개인화폴더\A9878
# Created folder: ./static/data/개인화폴더\A9879
# Created folder: ./static/data/개인화폴더\A9880
# Created folder: ./static/data/개인화폴더\A9881
# Created folder: ./static/data/개인화폴더\A9882
# Created folder: ./static/data/개인화폴더\A9883
# Created folder: ./static/data/개인화폴더\A9884
# Created folder: ./static/data/개인화폴더\A9885
# Created folder: ./static/data/개인화폴더\A9886
# Created folder: ./static/data/개인화폴더\A9887
# Created folder: ./static/data/개인화폴더\A9888
# Created folder: ./static/data/개인화폴더\A9889
# Created folder: ./static/data/개인화폴더\A9890
# Created folder: ./static/data/개인화폴더\A9891
# Created folder: ./static/data/개인화폴더\A9892
# Created folder: ./static/data/개인화폴더\A9893
# Created folder: ./static/data/개인화폴더\A9894
# Created folder: ./static/data/개인화폴더\A9895
# Created folder: ./static/data/개인화폴더\A9896
# Created folder: ./static/data/개인화폴더\A9897
# Created folder: ./static/data/개인화폴더\A9898
# Created folder: ./static/data/개인화폴더\A9899
# Created folder: ./static/data/개인화폴더\A9900
# Created folder: ./static/data/개인화폴더\A9901
# Created folder: ./static/data/개인화폴더\A9902
# Created folder: ./static/data/개인화폴더\A9903
# Created folder: ./static/data/개인화폴더\A9904
# Created folder: ./static/data/개인화폴더\A9905
# Created folder: ./static/data/개인화폴더\A9906
# Created folder: ./static/data/개인화폴더\A9907
# Created folder: ./static/data/개인화폴더\A9908
# Created folder: ./static/data/개인화폴더\A9909
# Created folder: ./static/data/개인화폴더\A9910
# Created folder: ./static/data/개인화폴더\A9911
# Created folder: ./static/data/개인화폴더\A9912
# Created folder: ./static/data/개인화폴더\A9913
# Created folder: ./static/data/개인화폴더\A9914
# Created folder: ./static/data/개인화폴더\A9915
# Created folder: ./static/data/개인화폴더\A9916
# Created folder: ./static/data/개인화폴더\A9917
# Created folder: ./static/data/개인화폴더\A9918
# Created folder: ./static/data/개인화폴더\A9919
# Created folder: ./static/data/개인화폴더\A9920
# Created folder: ./static/data/개인화폴더\A9921
# Created folder: ./static/data/개인화폴더\A9922
# Created folder: ./static/data/개인화폴더\A9923
# Created folder: ./static/data/개인화폴더\A9924
# Created folder: ./static/data/개인화폴더\A9925
# Created folder: ./static/data/개인화폴더\A9926
# Created folder: ./static/data/개인화폴더\A9927
# Created folder: ./static/data/개인화폴더\A9928
# Created folder: ./static/data/개인화폴더\A9929
# Created folder: ./static/data/개인화폴더\A9930
# Created folder: ./static/data/개인화폴더\A9931
# Created folder: ./static/data/개인화폴더\A9932
# Created folder: ./static/data/개인화폴더\A9933
# Created folder: ./static/data/개인화폴더\A9934
# Created folder: ./static/data/개인화폴더\A9935
# Created folder: ./static/data/개인화폴더\A9936
# Created folder: ./static/data/개인화폴더\A9937
# Created folder: ./static/data/개인화폴더\A9938
# Created folder: ./static/data/개인화폴더\A9939
# Created folder: ./static/data/개인화폴더\A9940
# Created folder: ./static/data/개인화폴더\A9941
# Created folder: ./static/data/개인화폴더\A9942
# Created folder: ./static/data/개인화폴더\A9943
# Created folder: ./static/data/개인화폴더\A9944
# Created folder: ./static/data/개인화폴더\A9945
# Created folder: ./static/data/개인화폴더\A9946
# Created folder: ./static/data/개인화폴더\A9947
# Created folder: ./static/data/개인화폴더\A9948
# Created folder: ./static/data/개인화폴더\A9949
# Created folder: ./static/data/개인화폴더\A9950
# Created folder: ./static/data/개인화폴더\A9951
# Created folder: ./static/data/개인화폴더\A9952
# Created folder: ./static/data/개인화폴더\A9953
# Created folder: ./static/data/개인화폴더\A9954
# Created folder: ./static/data/개인화폴더\A9955
# Created folder: ./static/data/개인화폴더\A9956
# Created folder: ./static/data/개인화폴더\A9957
# Created folder: ./static/data/개인화폴더\A9958
# Created folder: ./static/data/개인화폴더\A9959
# Created folder: ./static/data/개인화폴더\A9960
# Created folder: ./static/data/개인화폴더\A9961
# Created folder: ./static/data/개인화폴더\A9962
# Created folder: ./static/data/개인화폴더\A9963
# Created folder: ./static/data/개인화폴더\A9964
# Created folder: ./static/data/개인화폴더\A9965
# Created folder: ./static/data/개인화폴더\A9966
# Created folder: ./static/data/개인화폴더\A9967
# Created folder: ./static/data/개인화폴더\A9968
# Created folder: ./static/data/개인화폴더\A9969
# Created folder: ./static/data/개인화폴더\A9970
# Created folder: ./static/data/개인화폴더\A9971
# Created folder: ./static/data/개인화폴더\A9972
# Created folder: ./static/data/개인화폴더\A9973
# Created folder: ./static/data/개인화폴더\A9974
# Created folder: ./static/data/개인화폴더\A9975
# Created folder: ./static/data/개인화폴더\A9976
# Created folder: ./static/data/개인화폴더\A9977
# Created folder: ./static/data/개인화폴더\A9978
# Created folder: ./static/data/개인화폴더\A9979
# Created folder: ./static/data/개인화폴더\A9980
# Created folder: ./static/data/개인화폴더\A9981
# Created folder: ./static/data/개인화폴더\A9982
# Created folder: ./static/data/개인화폴더\A9983
# Created folder: ./static/data/개인화폴더\A9984
# Created folder: ./static/data/개인화폴더\A9985
# Created folder: ./static/data/개인화폴더\A9986
# Created folder: ./static/data/개인화폴더\A9987
# Created folder: ./static/data/개인화폴더\A9988
# Created folder: ./static/data/개인화폴더\A9989
# Created folder: ./static/data/개인화폴더\A9990
# Created folder: ./static/data/개인화폴더\A9991
# Created folder: ./static/data/개인화폴더\A9992
# Created folder: ./static/data/개인화폴더\A9993
# Created folder: ./static/data/개인화폴더\A9994
# Created folder: ./static/data/개인화폴더\A9995
# Created folder: ./static/data/개인화폴더\A9996
# Created folder: ./static/data/개인화폴더\A9997
# Created folder: ./static/data/개인화폴더\A9998
# Created folder: ./static/data/개인화폴더\A9999
# Folder creation completed.

# %%
data = pd.read_excel("C:/Users/windows11/Downloads/신분증 (통합본).xls")

# %%
data = pd.concat([data[:1],data]).reset_index(drop=True)

# %%
data[:1] = data.columns
# Out:
# C:\Users\windows11\AppData\Local\Temp\ipykernel_22332\1687491274.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unnamed: 5' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data[:1] = data.columns
# C:\Users\windows11\AppData\Local\Temp\ipykernel_22332\1687491274.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unnamed: 8' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data[:1] = data.columns
# C:\Users\windows11\AppData\Local\Temp\ipykernel_22332\1687491274.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unnamed: 9' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data[:1] = data.columns
# C:\Users\windows11\AppData\Local\Temp\ipykernel_22332\1687491274.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unnamed: 10' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data[:1] = data.columns
# C:\Users\windows11\AppData\Local\Temp\ipykernel_22332\1687491274.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unnamed: 11' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data[:1] = data.columns

# %%
temp = data[-data['성명'].isna()].reset_index(drop=True)

# %%
temp
# Out:
#       Unnamed: 0  성명                                               장해룡  주민번호  \
# 0     Unnamed: 0  성명                                               장해룡  주민번호
# 1            NaN  주소                     경기도 시흥시 정왕동 2327-1 월드프라자 403호   NaN
# 2            NaN  성명                                               김준호  주민번호
# 3            NaN  주소  서울특별시 마포구 양화로 72, 101동 1813호(서교동, 서교동 효성 해링턴 타워)   NaN
# 4            NaN  성명                                               송원준  주민번호
# ...          ...  ..                                               ...   ...
# 1973         NaN  주소                                               NaN   NaN
# 1974         NaN  성명                                               NaN  주민번호
# 1975         NaN  주소                                               NaN   NaN
# 1976         NaN  성명                                               NaN  주민번호
# 1977         NaN  주소                                               NaN   NaN
#
#       710228-5140595  Unnamed: 5  등록번호  Unnamed: 7  Unnamed: 8  Unnamed: 9  \
# 0     710228-5140595  Unnamed: 5  등록번호  Unnamed: 7  Unnamed: 8  Unnamed: 9
# 1                NaN         NaN   NaN         NaN         NaN         NaN
# 2     910919-1169717         NaN  등록번호         NaN         NaN         NaN
# 3                NaN         NaN   NaN         NaN         NaN         NaN
# 4     641103-1057721         NaN  등록번호         NaN         NaN         NaN
# ...              ...         ...   ...         ...         ...         ...
# 1973             NaN         NaN   NaN         NaN         NaN         NaN
# 1974             NaN         NaN  등록번호         NaN         NaN         NaN
# 1975             NaN         NaN   NaN         NaN         NaN         NaN
# 1976             NaN         NaN  등록번호         NaN         NaN         NaN
# 1977             NaN         NaN   NaN         NaN         NaN         NaN
#
#       Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0     Unnamed: 10  Unnamed: 11  Unnamed: 12
# 1             NaN          NaN          NaN
# 2             NaN          NaN          NaN
# 3             NaN          NaN          NaN
# 4             NaN          NaN          NaN
# ...           ...          ...          ...
# 1973          NaN          NaN          NaN
# 1974          NaN          NaN          NaN
# 1975          NaN          NaN          NaN
# 1976          NaN          NaN          NaN
# 1977          NaN          NaN          NaN
#
# [1978 rows x 13 columns]

# %%
1978/2
# Out:
# 989.0

# %%
(2966-2)/3
# Out:
# 988.0

# %%
import numpy as np

# %%
new_data = pd.DataFrame({'성명':[],'주민번호':[],'주소':[]})
for i in range(989):
    kk = 0+i*2
    kk2 = 1+i*2
    
    dd1 = temp.iloc[kk,:]
    dd2 = temp.iloc[kk2,:]
    dd = pd.DataFrame({'성명':[dd1[2]],"주민번호":[dd1[4]],"주소":[dd2[2]]})
    new_data = pd.concat([new_data,dd]).reset_index(drop=True)
# Out:
# C:\Users\windows11\AppData\Local\Temp\ipykernel_22332\636739569.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   dd = pd.DataFrame({'성명':[dd1[2]],"주민번호":[dd1[4]],"주소":[dd2[2]]})

# %%
new_data2 = new_data[-new_data['성명'].isna()].reset_index(drop=True)

# %%
for i in range(len(new_data2)):
    if(i+1<10):
        new_data2.loc[i,'고유번호'] = "A000"+str(i+1)
    elif(i+1<100):
        new_data2.loc[i,'고유번호'] = "A00"+str(i+1)
    elif(i+1<1000):
        new_data2.loc[i,'고유번호'] = "A0"+str(i+1)
    else:
        new_data2.loc[i,'고유번호'] = "A"+str(i+1)

# %%
new_data2.to_excel("C:/Users/windows11/Downloads/신분증_데이터.xlsx",index=False)

# %%
data = pd.read_csv("./static/data/ranktable.csv")

# %%
data
# Out:
#    랭킹         현장 총괄 이름   G  C  A   L  Total
# 0   1   시흥 한라 태일   정동근  50  3  5  -5     53
# 1   2     김포 대우    황민권  30  2  4 -20     16
# 2   3  마곡 신세계 휘강   이운호  10  1  3   0     14

# %%
data['작업장명'] = '당진'

data2 = data.copy()
data2['작업장명'] = '시흥'

data3 = data.copy()
data3['작업장명'] = '마곡'


data_full = pd.concat([data,data2,data3])

# %%
import json,simplejson

# %%
data_json = data.to_json(orient='records')

# %%
pd.read_excel("./static/data/INSA_DB.xlsx")
# Out:
#      성명          영문명 체류비자    국적          KEY_ID       ID PASSWORD ADMIN
# 0   이동성  LEEDONGSUNG  NaN   NaN             NaN   Login0      aaa     Y
# 1   이동명  LI DONGMING  F-4    중국  700426-1182619   Login1      aaa     N
# 2   진종열          JIN  F-5    중국  640607-1011421   Login2      aaa     N
# 3   신승준         SHIN  F-2    중국  911108-1169428   Login3      aaa     N
# 4   김성웅          KIM  F-4    중국  620318-5780290   Login4      aaa     N
# 5   서룡남          SEO  NaN  대한민국  731120-5780179   Login5      aaa     N
# 6   장해룡         Jang  NaN  대한민국  910128-5100039   Login6      aaa     N
# 7    윤혁      WUEN HE  NaN  대한민국  650720-5102297   Login7      aaa     N
# 8   문종근          MUN  NaN  대한민국  660305-5260491   Login8      aaa     N
# 9   정성하       JUNGSH  NaN  대한민국  650110-5920025   Login9      aaa     N
# 10  송석구       SONGSS  NaN  대한민국  640825-5100033  Login10      aaa     N
# 11  허철용           HA  NaN  대한민국  770701-5760034  Login11      aaa     N

# %%
import pandas as pd

# 파일명
file_name = 'test.xlsx'

# Daraframe형식으로 엑셀 파일 읽기
df = pd.read_excel(file_name)

# 데이터 프레임 출력
print(df)
# Out:
# [{'랭킹': 1,
#   '현장': '시흥 한라 태일',
#   '총괄 이름': '정동근',
#   'G': 50,
#   'C': 3,
#   'A': 5,
#   'L': -5,
#   'Total': 53},
#  {'랭킹': 2,
#   '현장': '김포 대우 ',
#   '총괄 이름': '황민권',
#   'G': 30,
#   'C': 2,
#   'A': 4,
#   'L': -20,
#   'Total': 16},
#  {'랭킹': 3,
#   '현장': '마곡 신세계 휘강',
#   '총괄 이름': '이운호',
#   'G': 10,
#   'C': 1,
#   'A': 3,
#   'L': 0,
#   'Total': 14}]

# %%
with open("./static/data/ranktable.json", "w", encoding='UTF-8') as json_file:
    json.dump(json.loads(data_json), json_file, ensure_ascii = False)

# %%
# !pip install requests
# Out:
# Collecting requests
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ---------------------------------------- 64.9/64.9 KB ? eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.6.2-py3-none-any.whl (164 kB)
#      -------------------------------------- 164.4/164.4 KB 5.0 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.2-py3-none-any.whl (121 kB)
#      ---------------------------------------- 121.4/121.4 KB ? eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp39-cp39-win_amd64.whl (100 kB)
#      -------------------------------------- 100.4/100.4 KB 5.6 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ---------------------------------------- 66.8/66.8 KB ? eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.6.2 charset-normalizer-3.3.2 idna-3.7 requests-2.32.3 urllib3-2.2.2
# WARNING: You are using pip version 22.0.4; however, version 24.1 is available.
# You should consider upgrading via the 'C:\Users\windows11\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# 네이버 웍스 API 엔드포인트 URL
url = 'https://www.worksapis.com/v1.0/sharedrives'

# 네이버 웍스에서 발급받은 클라이언트 아이디와 시크릿
client_id = '8zESjIVD54_8K5PA_dIu'
client_secret = 'wyWAH1uLEY'

# 네이버 웍스 API에 접근할 때 사용할 토큰
access_token = 'your_access_token'

# API 요청 헤더 설정
headers = {
    'Content-Type': 'application/json',
    'consumerKey': client_id,
    'Authorization': f'Bearer {access_token}'
}

# API 요청 보내기 (GET 요청 예제)
response = requests.get(url, headers=headers)

# 응답 확인
if response.status_code == 200:
    # API 응답이 JSON 형식이라면
    drive_info = response.json()
    print(drive_info)
else:
    print(f'Error: {response.status_code}')
    print(response.text)
# Out:
# Error: 401
# {"code":"UNAUTHORIZED","description":"Malformed authentication token"}

# %%
from requests_oauthlib import OAuth2Session
from oauthlib.oauth2 import BackendApplicationClient
import secrets

# OAuth 클라이언트 생성
client = BackendApplicationClient(client_id=client_id)
oauth = OAuth2Session(client=client)

# state 값 생성
state = secrets.token_urlsafe(16)  # 16바이트 길이의 URL 안전한 무작위 문자열 생성

# nonce 값 생성 (OIDC에서 사용될 경우)
nonce = secrets.token_urlsafe(16)  # 16바이트 길이의 URL 안전한 무작위 문자열 생성
# 네이버 웍스 API 엔드포인트 URL
api_url = 'https://www.worksapis.com/v1.0/sharedrives'

# 네이버 웍스에서 발급받은 클라이언트 아이디와 시크릿
client_id = '8zESjIVD54_8K5PA_dIu'
client_secret = 'wyWAH1uLEY'
Redirect_URL = "https://seowoohr.ncpworkplace.com/v/home/"
scope ='openid'
code = "code"
state = "YOUR_STATE"
nonce = 'aaa'
# OAuth 클라이언트 생성
token_url = f"https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id={client_id}&redirect_uri={Redirect_URL}&scope={scope}&response_type={code}&state={state}&nonce={nonce}"

# %%
token_url
# Out:
# 'https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id=8zESjIVD54_8K5PA_dIu&redirect_uri=https://seowoohr.ncpworkplace.com/v/home/&scope=openid&response_type=code&state=YOUR_STATE&nonce=aaa'

# %%
event = {'summary': 'Testmessage', 
             'description':'{"numworkers":"","workersnormal":"","workershard":"","workersmorning":"","specialnotes":"","overtime":""}',
               'start': {'dateTime':'2024-07-06T14:00:00', 'timeZone':'Asia/Seoul'},
                 'recurrence': [], 'recurringEventId': 'TZID=Asia/Seoul:2025-04-05'}

# %%
event['description'].replace(":",":\n\n ").replace(",","\n ").replace('"',"").replace("numworkers","작업인원").\
replace("workersnormal","일반 근무자").replace("workershard","추가 근무자").replace("workersmorning","오전근무자").\
replace("taskresult","작업내용").replace("specialnotes","특이사항").replace("overtime","추가근무")
# Out:
# '{작업인원:\n workersnormal:\n workershard:\n workersmorning:\n specialnotes:\n overtime:}'

# %%
from requests_oauthlib import OAuth2Session
from oauthlib.oauth2 import BackendApplicationClient
import secrets

# OAuth 클라이언트 생성
client = BackendApplicationClient(client_id=client_id)
oauth = OAuth2Session(client=client)

# state 값 생성
state = secrets.token_urlsafe(16)  # 16바이트 길이의 URL 안전한 무작위 문자열 생성

# nonce 값 생성 (OIDC에서 사용될 경우)
nonce = secrets.token_urlsafe(16)  # 16바이트 길이의 URL 안전한 무작위 문자열 생성
# 네이버 웍스 API 엔드포인트 URL
api_url = 'https://www.worksapis.com/v1.0/sharedrives'

# 네이버 웍스에서 발급받은 클라이언트 아이디와 시크릿
client_id = '8zESjIVD54_8K5PA_dIu'
client_secret = 'wyWAH1uLEY'
Redirect_URL = "https://seowoohr.ncpworkplace.com/v/home/"
scope ='openid'
code = "code"
state = "YOUR_STATE"
nonce = 'aaa'

# OAuth 클라이언트 생성
token_url = "https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id={client_id}&redirect_uri={Redirect_URL}&scope={scope}&response_type={code}&state={state}&nonce={nonce}"
print(token_url)
token = oauth.fetch_token(token_url=token_url, client_id=client_id, client_secret=client_secret)

# API 호출
response = oauth.get(api_url)
# Out:
# https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id={client_id}&redirect_uri={Redirect_URL}&scope={scope}&response_type={code}&state={state}&nonce={nonce}
# ---------------------------------------------------------------------------
# MissingTokenError                         Traceback (most recent call last)
# Cell In[5], line 29
#      27 token_url = "https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id={client_id}&redirect_uri={Redirect_URL}&scope={scope}&response_type={code}&state={state}&nonce={nonce}"
#      28 print(token_url)
# ---> 29 token = oauth.fetch_token(token_url=token_url, client_id=client_id, client_secret=client_secret)
#      31 # API 호출
#      32 response = oauth.get(api_url)
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\requests_oauthlib\oauth2_session.py:406, in OAuth2Session.fetch_token(self, token_url, code, authorization_response, body, auth, username, password, method, force_querystring, timeout, headers, verify, proxies, include_client_id, client_secret, cert, **kwargs)
#     403     log.debug("Invoking hook %s.", hook)
#     404     r = hook(r)
# --> 406 self._client.parse_request_body_response(r.text, scope=self.scope)
#     407 self.token = self._client.token
#     408 log.debug("Obtained token %s.", self.token)
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\oauthlib\oauth2\rfc6749\clients\base.py:427, in Client.parse_request_body_response(self, body, scope, **kwargs)
#     379 """Parse the JSON response body.
#     380
#     381 If the access token request is valid and authorized, the
#    (...)
#     424 .. _`Section 7.1`: https://tools.ietf.org/html/rfc6749#section-7.1
#     425 """
#     426 scope = self.scope if scope is None else scope
# --> 427 self.token = parse_token_response(body, scope=scope)
#     428 self.populate_token_attributes(self.token)
#     429 return self.token
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\oauthlib\oauth2\rfc6749\parameters.py:441, in parse_token_response(body, scope)
#     438         params['expires_at'] = time.time() + int(params['expires_in'])
#     440 params = OAuth2Token(params, old_scope=scope)
# --> 441 validate_token_parameters(params)
#     442 return params
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\oauthlib\oauth2\rfc6749\parameters.py:451, in validate_token_parameters(params)
#     448     raise_from_error(params.get('error'), params)
#     450 if not 'access_token' in params:
# --> 451     raise MissingTokenError(description="Missing access token parameter.")
#     453 if not 'token_type' in params:
#     454     if os.environ.get('OAUTHLIB_STRICT_TOKEN_TYPE'):
#
# MissingTokenError: (missing_token) Missing access token parameter.

# %%
response
# Out:
# <Response [500]>

# %%
import requests
import secrets

# state 값 생성
state = secrets.token_urlsafe(16)  # 16바이트 길이의 URL 안전한 무작위 문자열 생성

# nonce 값 생성 (OIDC에서 사용될 경우)
nonce = secrets.token_urlsafe(16)  # 16바이트 길이의 URL 안전한 무작위 문자열 생성
# 네이버 웍스 API 엔드포인트 URL
api_url = 'https://www.worksapis.com/v1.0/sharedrives'

# 네이버 웍스에서 발급받은 클라이언트 아이디와 시크릿
client_id = '8zESjIVD54_8K5PA_dIu'
client_secret = 'wyWAH1uLEY'
Redirect_URL = "https://seowoohr.ncpworkplace.com/v/home/"
scope ='openid'
code = "code"
# OAuth 클라이언트 생성
token_url = "https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id={Client_ID}&redirect_uri={Redirect_URL}&scope={Scope}&response_type={code}&state={state}&nonce={nonce}"

# 토큰 요청을 위한 데이터
token_data = {
    'grant_type': 'client_credentials',
    'client_id': client_id,
    'client_secret': client_secret
}

# 토큰 요청 보내기 (POST 요청)
response = requests.post(token_url, data=token_data)

# 응답 확인
if response.status_code == 200:
    token_info = response.json()
    access_token = token_info['access_token']
    print(f'액세스 토큰: {access_token}')
else:
    print(f'Error: {response.status_code}')
    print(response.text)
# Out:
# Error: 500
#
#
#
#
#
#
#
#
# <!DOCTYPE HTML>
# <html lang="ko">
# <head>
# <meta charset="utf-8" />
# 	<title>NAVER WORKS</title>
# 	<meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
# 	<meta name="viewport" content="width=device-width,initial-scale=1.0"/>
# 	<link type="text/css" rel="stylesheet" href="/css/admin.css;jsessionid=E3DFD96549B313F7F41BB3FA7149B2CB.nwe_auth?20240625">
# </head>
# <body>
# <div>
#     <a href="#content" class="skip"></a>
#     <!-- ncs / region_kr / region_jp-->
#     <div class="wrap   region_kr">
#         <header class="header error_header">
#             <h1 class="corp">
#                 <a href="#"><i class="blind">NAVER WORKS</i></a>
#             </h1>
#         </header>
#         <div class="error_wrap not_found">
#             <div class="inner_cover">
#                 <div class="hero">Page not found.
#                 </div>
#                 <p class="msg">The internet address may have been entered incorrectly, or the page may have been changed or deleted.<br>Please double check that you have entered the correct address.</p>
#                 <div class="btn_cover">
#                     <a href="#" class="lw_btn" onclick="javascript:history.back();">Previous page</a>
#                 </div>
#             </div>
#         </div>
#     </div>
# </div>
# </body>
# </html>

# %%
import requests
from flask import Flask, request, redirect, url_for
from urllib.parse import urlencode

# OAuth 2.0 인증 정보
client_id = '8zESjIVD54_8K5PA_dIu'
client_secret = 'wyWAH1uLEY'
redirect_uri = 'https://mail.worksmobile.com/'
auth_url = 'https://auth.worksmobile.com/oauth2/v2.0/authorize'
token_url = 'https://auth.worksmobile.com/oauth2/v2.0/token'

# 인증 요청 URL 생성
auth_params = {
    'client_id': client_id,
    'redirect_uri': redirect_uri,
    'scope': 'openid',  # 필요에 따라 범위 조정
    'response_type': 'code',
    'state': 'random_state_string',
    "nonce":"NONCE_ASSDF"
}

auth_request_url = f"{auth_url}?{urlencode(auth_params)}"
print(f"Visit this URL to authorize the application: {auth_request_url}")
# Out:
# Visit this URL to authorize the application: https://auth.worksmobile.com/oauth2/v2.0/authorize?client_id=8zESjIVD54_8K5PA_dIu&redirect_uri=https%3A%2F%2Fmail.worksmobile.com%2F&scope=openid&response_type=code&state=random_state_string&nonce=NONCE_ASSDF

# %%
from flask import Flask, request, redirect, url_for, session,jsonify,render_template
import requests
# 캘린더 API 엔드포인트
calendarId = 'c_300029314_8d914568-af3f-4ac8-b9eb-e968f8547c08'
userId = "abcd00pi@seowoohr.com"
access_token = ".kwiu9yNovfcs8Rumz2QSOg"
calendar_url = f'https://www.worksapis.com/v1.0/users/{userId}/calendars/{calendarId}/events'

# API 요청 헤더
headers = {
    'Authorization': f'Bearer {access_token}',
    'Content-Type': 'application/json'
}

# 캘린더 이벤트 요청
response = requests.get(calendar_url, headers=headers,params={"fromDateTime":"2024-05-01T10:00:00%2B09:00",
                                                            'untilDateTime':"2024-06-01T10:00:00%2B09:00"})
events = response.json()

# 이벤트 출력
print(events)
# Out:
# {'events': []}

# %%
for i in range(len(events['events'][0]['eventComponents'])):
    temp = events['events'][0]['eventComponents'][i]
    print(temp['summary'])
# Out:
# 업무 자동화 화상 미팅 21시

# %%
import os

##로컬PC 경로
original_working_directory = os.getcwd()
original_working_directory
# Out:
# 'c:\\Users\\windows11\\OneDrive\\문서\\seowoo\\flask'

# %%
import os

##로컬PC 경로
original_working_directory = os.getcwd()

""" 로컬PC에서 작업 """

## 네트워크 폴더로 이동
new_networked_directory = r'D:\\네이버웍스\\NAVER WORKS Drive\\. Public_Root'
os.chdir(new_networked_directory)

# %%
net_dir = r'D:/네이버웍스/NAVER WORKS Drive/. Public_Root/외주@2001000000403897/test.json'

files_and_folders = os.listdir(r'D:/네이버웍스/NAVER WORKS Drive/. Public_Root/외주@2001000000403897')
files_and_folders
# Out:
# ['240612_작업.xlsm',
#  '240612_작업_설명1.mp4',
#  '240613_질문.pptx',
#  '240618_작업.xlsm',
#  '240618_작업_설명.mp4',
#  'desktop.ini',
#  'test.csv',
#  'test.json',
#  '논의내용_0617.pptm',
#  '송도2024구간별정리.xlsx']

# %%
import json
with open(net_dir, 'r', encoding='utf-8') as file:
    data = json.load(file)

# %%
import pandas as pd
pd.read_json(net_dir)
net_dir
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 import pandas as pd
# ----> 2 pd.read_json(net_dir)
#       3 net_dir
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:815, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     813     return json_reader
#     814 else:
# --> 815     return json_reader.read()
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:1025, in JsonReader.read(self)
#    1023         obj = self._get_object_parser(self._combine_lines(data_lines))
#    1024 else:
# -> 1025     obj = self._get_object_parser(self.data)
#    1026 if self.dtype_backend is not lib.no_default:
#    1027     return obj.convert_dtypes(
#    1028         infer_objects=False, dtype_backend=self.dtype_backend
#    1029     )
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:1051, in JsonReader._get_object_parser(self, json)
#    1049 obj = None
#    1050 if typ == "frame":
# -> 1051     obj = FrameParser(json, **kwargs).parse()
#    1053 if typ == "series" or obj is None:
#    1054     if not isinstance(dtype, bool):
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:1187, in Parser.parse(self)
#    1185 @final
#    1186 def parse(self):
# -> 1187     self._parse()
#    1189     if self.obj is None:
#    1190         return None
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\json\_json.py:1402, in FrameParser._parse(self)
#    1399 orient = self.orient
#    1401 if orient == "columns":
# -> 1402     self.obj = DataFrame(
#    1403         ujson_loads(json, precise_float=self.precise_float), dtype=None
#    1404     )
#    1405 elif orient == "split":
#    1406     decoded = {
#    1407         str(k): v
#    1408         for k, v in ujson_loads(json, precise_float=self.precise_float).items()
#    1409     }
#
# File c:\Users\windows11\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:875, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     872 # For data is scalar
#     873 else:
#     874     if index is None or columns is None:
# --> 875         raise ValueError("DataFrame constructor not properly called!")
#     877     index = ensure_index(index)
#     878     columns = ensure_index(columns)
#
# ValueError: DataFrame constructor not properly called!

# %%
# # 리디렉션된 URL에서 코드 추출
auth_code = input('Enter the authorization code: ')
print(auth_code)
#auth_code = "mail"
# 액세스 토큰 요청
token_data = {
    'grant_type': 'authorization_code',
    'code': auth_code,
    'client_id': client_id,
    'client_secret': client_secret,
    'redirect_uri': redirect_uri
}
print("여기 대써?! ")
token_response = requests.post(token_url, data=token_data)
token_info = token_response.json()
print(token_info)
access_token = token_info['id_token']
# Out:
# 여기 대써?!
# {'error_description': 'Access token or refresh token or authorization code is not valid.', 'error': 'invalid_request', 'error_uri': 'See document on https://developers.worksmobile.com/docs/auth-oauth'}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 17
#      15 token_info = token_response.json()
#      16 print(token_info)
# ---> 17 access_token = token_info['id_token']
#
# KeyError: 'id_token'

# %%
# OAuth 2.0 인증 정보
user_id = 'abcd00pi'
headers = {
    'Authorization': f'Bearer {access_token}'
}
print(headers)
# 메일함 목록 조회
mailfolders_url = f'https://www.worksapis.com/v1.0/users/{user_id}/mail/mailfolders'

# 첫 번째 요청
response = requests.get(mailfolders_url, headers=headers, allow_redirects=True)


mailfolders = response.json().get('mailfolders', [])



# 메일함 목록 출력
for folder in mailfolders:
    print(f"Folder ID: {folder['folderId']}, Name: {folder['folderName']}, Unread Count: {folder['unreadMailCount']}, Total Count: {folder['mailCount']}")
# Out:
# {'Authorization': 'Bearer eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsImtpZCI6Im9oWmdSeTdjb2ZNSFZsZDN4aGpqc005RndoNGRDdFE3N3VjM2MzdGcifQ.eyJpc3MiOiJodHRwczovL2F1dGgud29ya3Ntb2JpbGUuY29tIiwic3ViIjoiZWNhNjZkZjYtODI3NC00YjZiLTFhMzgtMDNmYmQxYmNjOTM4IiwiYXVkIjoiOHpFU2pJVkQ1NF84SzVQQV9kSXUiLCJub25jZSI6Ik5PTkNFX0FTU0RGIiwiZXhwIjoxNzE5NzA4MzkzLCJpYXQiOjE3MTk3MDQ3OTN9.lXFXZE64BgGou3mGK39Y9M-Bz_CfBatbwM7vAQYamPr5QH2d4SXgczF9Iv1AxLvfKKCAj1io2_-LipmDTfGqInnnel2uU_pW4yjT7b9V5ZPuvWXmot8sDg105ORVT4M3MrHV_rTaGjOGAp8Ek0ZPmHjc_MYrVlsjePXQ3lGMXKSENRzM8nbEsITJPAw2-qtcsz2W40751wsLyp5kPDoQodz2_ttc4QckMmHJJC0PuIaKgKKIjUhlk9h3KUxGNvfdPIJEHRMhKOfIPgSE3A44-Hr-HFHCGNVY14x5RB_mkoBVIq-L7102cU8g9K4sHpKbGSVsPXvnG_Cp_YXE1hOR_w'}

# %%
response
# Out:
# <Response [401]>

# %%
import pandas as pd

# 이메일 조회 API 호출
email_api_url = 'https://www.worksapis.com/v1.0/users/{abcd00pi}/mail/{mailid}'
headers = {
    'Authorization': f'Bearer {access_token}'
}
params = {
    'folderSN': '0',  # 기본 받은 편지함
    'limit': 10,  # 조회할 이메일 수
    'fields': 'subject,from,receivedTime'
}



response = requests.get(email_api_url, headers=headers, params=params)
emails = response.json().get('mails', [])

# 이메일 정보를 DataFrame으로 변환
email_data = []
for email in emails:
    email_data.append({
        'Subject': email['subject'],
        'Sender': email['from']['name'],
        'Date': email['receivedTime']
    })

df = pd.DataFrame(email_data)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
